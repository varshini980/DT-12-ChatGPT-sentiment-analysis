# %%
# Importing necessary libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import pandas as pd
import re

# Download NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Load your dataset (replace the file path with your actual file)
df = pd.read_csv("/Users/mohammadafsheen/Desktop/DT-12-ChatGPT-sentiment-analysis/file.csv")

# Ensure all non-string values are handled
df['tweets'] = df['tweets'].fillna('').astype(str)

# Step 1: Cleaning the text
cleaned = []
for text in df['tweets']:
    cleaned_text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation and special characters
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replace multiple spaces with a single space
    cleaned.append(cleaned_text.strip())  # Strip leading/trailing spaces

# Step 2: Tokenizing the cleaned text
tokens = [word_tokenize(x) for x in cleaned]

# Step 3: Removing stopwords
stop = set(stopwords.words('english'))
stpktn = [[word for word in sentence if word not in stop] for sentence in tokens]

# Step 4: Displaying results
print("Cleaned Text:", cleaned[:5])  # Display first 5 cleaned texts
print("Tokens:", tokens[:5])  # Display tokens for the first 5 cleaned texts
print("Tokens without Stopwords:", stpktn[:5])  # Display tokens without stopwords for the first 5 cleaned texts
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mohammadafsheen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/mohammadafsheen/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mohammadafsheen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Cleaned Text: ['ChatGPT Optimizing Language Models for Dialogue httpstcoK9rKRygYyn OpenAI', 'Try talking with ChatGPT our new AI system which is optimized for dialogue Your feedback will help us improve it httpstcosHDm57g3Kr', 'ChatGPT Optimizing Language Models for Dialogue httpstcoGLEbMoKN6w AI MachineLearning DataScience ArtificialIntelligencennTrending AIML Article Identified amp Digested via Granola a MachineDriven RSS Bot by Ramsey Elbasheer httpstcoRprmAXUp34', 'THRILLED to share that ChatGPT our new model optimized for dialog is now public free and accessible to everyone httpstcodyvtHecYbd httpstcoDdhzhqhCBX httpstcol8qTLure71', 'As of 2 minutes ago OpenAI released their new ChatGPT nnAnd you can use it right now httpstcoVyPGPNw988 httpstcocSn5h6h1M1']
# Tokens: [['ChatGPT', 'Optimizing', 'Language', 'Models', 'for', 'Dialogue', 'httpstcoK9rKRygYyn', 'OpenAI'], ['Try', 'talking', 'with', 'ChatGPT', 'our', 'new', 'AI', 'system', 'which', 'is', 'optimized', 'for', 'dialogue', 'Your', 'feedback', 'will', 'help', 'us', 'improve', 'it', 'httpstcosHDm57g3Kr'], ['ChatGPT', 'Optimizing', 'Language', 'Models', 'for', 'Dialogue', 'httpstcoGLEbMoKN6w', 'AI', 'MachineLearning', 'DataScience', 'ArtificialIntelligencennTrending', 'AIML', 'Article', 'Identified', 'amp', 'Digested', 'via', 'Granola', 'a', 'MachineDriven', 'RSS', 'Bot', 'by', 'Ramsey', 'Elbasheer', 'httpstcoRprmAXUp34'], ['THRILLED', 'to', 'share', 'that', 'ChatGPT', 'our', 'new', 'model', 'optimized', 'for', 'dialog', 'is', 'now', 'public', 'free', 'and', 'accessible', 'to', 'everyone', 'httpstcodyvtHecYbd', 'httpstcoDdhzhqhCBX', 'httpstcol8qTLure71'], ['As', 'of', '2', 'minutes', 'ago', 'OpenAI', 'released', 'their', 'new', 'ChatGPT', 'nnAnd', 'you', 'can', 'use', 'it', 'right', 'now', 'httpstcoVyPGPNw988', 'httpstcocSn5h6h1M1']]
# Tokens without Stopwords: [['ChatGPT', 'Optimizing', 'Language', 'Models', 'Dialogue', 'httpstcoK9rKRygYyn', 'OpenAI'], ['Try', 'talking', 'ChatGPT', 'new', 'AI', 'system', 'optimized', 'dialogue', 'Your', 'feedback', 'help', 'us', 'improve', 'httpstcosHDm57g3Kr'], ['ChatGPT', 'Optimizing', 'Language', 'Models', 'Dialogue', 'httpstcoGLEbMoKN6w', 'AI', 'MachineLearning', 'DataScience', 'ArtificialIntelligencennTrending', 'AIML', 'Article', 'Identified', 'amp', 'Digested', 'via', 'Granola', 'MachineDriven', 'RSS', 'Bot', 'Ramsey', 'Elbasheer', 'httpstcoRprmAXUp34'], ['THRILLED', 'share', 'ChatGPT', 'new', 'model', 'optimized', 'dialog', 'public', 'free', 'accessible', 'everyone', 'httpstcodyvtHecYbd', 'httpstcoDdhzhqhCBX', 'httpstcol8qTLure71'], ['As', '2', 'minutes', 'ago', 'OpenAI', 'released', 'new', 'ChatGPT', 'nnAnd', 'use', 'right', 'httpstcoVyPGPNw988', 'httpstcocSn5h6h1M1']]

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests


# Load into a DataFrame
df = pd.read_csv("file.csv")

# Display the first 5 rows
print(df.head())
# Out:
#    Unnamed: 0                                             tweets   labels
# 0           0  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 1           1  Try talking with ChatGPT, our new AI system wh...     good
# 2           2  ChatGPT: Optimizing Language Models for Dialog...  neutral
# 3           3  THRILLED to share that ChatGPT, our new model ...     good
# 4           4  As of 2 minutes ago, @OpenAI released their ne...      bad

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv=TfidfVectorizer()

# %%
#importing multinomialnb
from sklearn.naive_bayes import MultinomialNB

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'tweets', 'labels'], dtype='object')

# %%
y=df['tweets']

# %%
y
# Out:
# 0         ChatGPT: Optimizing Language Models for Dialog...
# 1         Try talking with ChatGPT, our new AI system wh...
# 2         ChatGPT: Optimizing Language Models for Dialog...
# 3         THRILLED to share that ChatGPT, our new model ...
# 4         As of 2 minutes ago, @OpenAI released their ne...
#                                 ...
# 219289    Other Software Projects Are Now Trying to Repl...
# 219290    I asked #ChatGPT to write a #NYE Joke for SEOs...
# 219291    chatgpt is being disassembled until it can onl...
# 219292    2023 predictions by #chatGPT. Nothing really s...
# 219293     From ChatGPT, neat stuff https://t.co/qjjUF2Z2m0
# Name: tweets, Length: 219294, dtype: object

# %%
mb= MultinomialNB()

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()

# %%
ps.stem(df['tweets'][0])
# Out:
# 'chatgpt: optimizing language models for dialogue https://t.co/k9rkrygyyn @openai'

# %%
stemed_data=[]
for message in stpktn:
    stem=[ps.stem(word) for word in message]
    stemed_data.append(stem)

# %%
stemed_data
# Out:
# [['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcok9rkrygyyn',
#   'openai'],
#  ['tri',
#   'talk',
#   'chatgpt',
#   'new',
#   'ai',
#   'system',
#   'optim',
#   'dialogu',
#   'your',
#   'feedback',
#   'help',
#   'us',
#   'improv',
#   'httpstcoshdm57g3kr'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcoglebmokn6w',
#   'ai',
#   'machinelearn',
#   'datasci',
#   'artificialintelligencenntrend',
#   'aiml',
#   'articl',
#   'identifi',
#   'amp',
#   'digest',
#   'via',
#   'granola',
#   'machinedriven',
#   'rss',
#   'bot',
#   'ramsey',
#   'elbash',
#   'httpstcorprmaxup34'],
#  ['thrill',
#   'share',
#   'chatgpt',
#   'new',
#   'model',
#   'optim',
#   'dialog',
#   'public',
#   'free',
#   'access',
#   'everyon',
#   'httpstcodyvthecybd',
#   'httpstcoddhzhqhcbx',
#   'httpstcol8qtlure71'],
#  ['as',
#   '2',
#   'minut',
#   'ago',
#   'openai',
#   'releas',
#   'new',
#   'chatgpt',
#   'nnand',
#   'use',
#   'right',
#   'httpstcovypgpnw988',
#   'httpstcocsn5h6h1m1'],
#  ['just',
#   'launch',
#   'chatgpt',
#   'new',
#   'ai',
#   'system',
#   'optim',
#   'dialogu',
#   'httpstcoarx6m0fflenntri',
#   'httpstcoym1gp5ba64'],
#  ['as',
#   '2',
#   'minut',
#   'ago',
#   'openai',
#   'releas',
#   'new',
#   'chatgpt',
#   'nnand',
#   'use',
#   'right',
#   'n',
#   'nhttpstcokucnwyhq1bnn',
#   'httpstcokce59xs0yg',
#   'httpstcocsn5h6h1m1'],
#  ['chatgpt',
#   'come',
#   'strong',
#   'refus',
#   'help',
#   'stalk',
#   'someon',
#   'agre',
#   'provid',
#   'someon',
#   'waldo',
#   'httpstcocvijerbw38'],
#  ['0penal',
#   'deploy',
#   'thing',
#   'ive',
#   'help',
#   'build',
#   'last',
#   'coupl',
#   'month',
#   'chatbot',
#   'base',
#   'gpt',
#   '3',
#   'im',
#   'realli',
#   'excit',
#   'share',
#   'vlnhttpstcozp7hniuxbunhttpstconisjlwhomw'],
#  ['research',
#   'preview',
#   'newest',
#   'model',
#   'chatgptnnwer',
#   'tri',
#   'someth',
#   'new',
#   'preview',
#   'free',
#   'immedi',
#   'avail',
#   'everyon',
#   'waitlist',
#   'httpstco0rdt7qnzrd'],
#  ['god',
#   'damn',
#   'it',
#   'openai',
#   'stop',
#   'announc',
#   'thing',
#   'i',
#   'am',
#   'too',
#   'busi',
#   'httpstcof7xd511faf'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguenl',
#   'httpstcodp4l586urinc',
#   'httpstcowmqgnsj7jp'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcoglebmokn6w',
#   'ai',
#   'machinelearn',
#   'datasci',
#   'artificialintelligencenntrend',
#   'aiml',
#   'articl',
#   'identifi',
#   'amp',
#   'digest',
#   'via',
#   'granola',
#   'machinedriven',
#   'rss',
#   'bot',
#   'ramsey',
#   'elbash',
#   'httpstcotizyoxgcnr'],
#  ['openai',
#   'announc',
#   'chatgpt',
#   'model',
#   'optim',
#   'dialogu',
#   'httpstcof5fwklje88'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstconq1hjt5s5c',
#   'n2'],
#  ['ai',
#   'techforgood',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'ai',
#   'techtrends2020',
#   'httpstco06sde2y4do'],
#  ['technic',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'ai',
#   'techseoboost',
#   'busi',
#   'via',
#   'httpstcosczdaj9gss'],
#  ['ai',
#   'model',
#   'set',
#   'becom',
#   'search',
#   'engin',
#   'futur',
#   'atm',
#   'still',
#   'struggl',
#   'verac',
#   'chatgpt',
#   'openai',
#   'base',
#   'gpt3',
#   'seonnhttpstcoqqz1g0foti'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcobrjfw34pdi',
#   'n2'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'new',
#   'ai',
#   'system',
#   'optim',
#   'dialogu',
#   'teach',
#   'seo',
#   'minutennth',
#   'result',
#   'httpstcob5b668ncsp'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstco0swypzjgbf',
#   'n2'],
#  ['just',
#   'launch',
#   'chatgpt',
#   'convers',
#   'ai',
#   'system',
#   'listen',
#   'learn',
#   'challeng',
#   'httpstcojmdbv8gc4a',
#   'nnhelp',
#   'us',
#   'make',
#   'better',
#   'tri',
#   'httpstcorn0dthzk2j'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcojrycgdz0gi'],
#  ['it',
#   'clear',
#   'chatgpt',
#   'train',
#   'avoid',
#   'prescript',
#   'answer',
#   'instead',
#   'counsel',
#   'human',
#   'reach',
#   'conclusionnnpres',
#   'trolli',
#   'problem',
#   'help',
#   'find',
#   'framework',
#   'think',
#   'itnnask',
#   'direct',
#   'openli',
#   'refus',
#   'httpstcosa8xhqtogq'],
#  ['the',
#   'chatgpt',
#   'research',
#   'preview',
#   'today',
#   'httpstco3bwpnoywac',
#   'excit',
#   'get',
#   'feedback',
#   'especi',
#   'help',
#   'understand',
#   'contextu',
#   'model',
#   'risk',
#   'see',
#   'detail',
#   'thread',
#   'chatgpt',
#   'feedback',
#   'contest',
#   'httpstcoqnzba9aztv'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstco5u0hkcwvqr',
#   'comment',
#   'httpstcouhizywhzsq'],
#  ['the',
#   'folk',
#   'openai',
#   'releas',
#   'chatgpt',
#   'it',
#   'look',
#   'like',
#   'key',
#   'innov',
#   'retain',
#   'inform',
#   'previou',
#   'prompt',
#   'nnat',
#   'last',
#   'i',
#   'start',
#   'construct',
#   'ai',
#   'wife',
#   'nnhttpstcor4nyjli74u',
#   'httpstcojkeuf8oqki'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguenlink',
#   'httpstcopkqzxuwvkjncom',
#   'httpstcorjaaza22lk'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'openai',
#   'httpstco1ucp6tprdt'],
#  ['just',
#   'nchatgpt',
#   'research',
#   'earli',
#   'stage',
#   'gpt3',
#   'optimis',
#   'chat',
#   'rememb',
#   'convers',
#   'openai',
#   'nhttpstco3rkubly8uo'],
#  ['chatgpt',
#   'research',
#   'preview',
#   'nnit',
#   'optim',
#   'dialogu',
#   'readi',
#   'convers',
#   'dont',
#   'shygiv',
#   'tri',
#   'help',
#   'us',
#   'make',
#   'betternnhttpstcogviygsslro'],
#  ['tri',
#   'talk',
#   'chatgpt',
#   'new',
#   'ai',
#   'system',
#   'optim',
#   'dialogu',
#   'your',
#   'feedback',
#   'help',
#   'us',
#   'improv',
#   'httpstcokpwohydtrc'],
#  ['chatgpt', 'optim', 'languag', 'model', 'dialogu', 'httpstco8p9gwj3a02'],
#  ['announc',
#   'research',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstco7q3ueqn1sj'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'honest',
#   'httpstcou3ojmukkkj',
#   'httpstcos0ptb2sjnt'],
#  ['chatgpt',
#   'train',
#   'humancentr',
#   'way',
#   'excit',
#   'play',
#   'clarif',
#   'uncertaintynn',
#   'httpstcoxjoarp7jyu'],
#  ['ok',
#   'openai',
#   'new',
#   'chatgpt',
#   'basic',
#   'gener',
#   'aiart',
#   'prompt',
#   'i',
#   'ask',
#   'onelin',
#   'question',
#   'type',
#   'answer',
#   'verbatim',
#   'straight',
#   'midjourney',
#   'boom',
#   'time',
#   'get',
#   'weird',
#   'httpstcosywdscuxxf'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'basic',
#   'python',
#   'gave',
#   'truli',
#   'educ',
#   'answer',
#   'i',
#   'learn',
#   'python',
#   'slowli',
#   'past',
#   'year',
#   'realli',
#   'help',
#   'synopsi',
#   'gave',
#   'httpstcomxaeimmy8i'],
#  ['chatgpt',
#   'curiou',
#   'behavior',
#   'often',
#   'start',
#   'say',
#   'doesnt',
#   'know',
#   'someth',
#   'tell',
#   'bunch',
#   'vagu',
#   'relat',
#   'stuff',
#   'final',
#   'actual',
#   'answer',
#   'question',
#   'httpstco4rklzphnh'],
#  ['googl',
#   'donenncompar',
#   'qualiti',
#   'respons',
#   'chatgpt',
#   'httpstcovgo7usvlib'],
#  ['chatgpt',
#   'first',
#   'look',
#   'httpstco16k2nlmooy',
#   'thi',
#   'thing',
#   'incred',
#   'educ',
#   'roleplay',
#   'wow',
#   'chatgpt',
#   'openai',
#   'ai',
#   'artificialintellig',
#   'gpt3'],
#  ['anoth',
#   'new',
#   'releas',
#   'chatgpt',
#   'free',
#   'avail',
#   'anyon',
#   'tri',
#   'right',
#   'check',
#   'httpstcooahjbfjtif',
#   'httpstcoxbglr3p3uq'],
#  ['ok',
#   'openai',
#   'drop',
#   'chatgpt',
#   'alreadi',
#   'httpstco2nitlskcaw',
#   'httpstcon6enuwzplc'],
#  ['well',
#   'i',
#   'quit',
#   'impress',
#   'chatgpt',
#   'far',
#   'look',
#   'like',
#   'safeti',
#   'transpar',
#   'taken',
#   'account',
#   'httpstcocyncaoy38i'],
#  ['play',
#   'around',
#   'chatgpt',
#   'releas',
#   'openainnit',
#   'like',
#   'gpt3',
#   'easi',
#   'use',
#   'interfac',
#   'chat',
#   'itnni',
#   'ask',
#   'make',
#   'million',
#   'dollar',
#   'write',
#   'line',
#   'code',
#   'morennif',
#   'anyth',
#   'overtak',
#   'googl',
#   'search',
#   'itll',
#   'like',
#   'someth',
#   'like',
#   'httpstconxzmcgn9eb'],
#  ['chatgpt', 'vs', 'riddl', 'httpstcoyupyod0u7o'],
#  ['openai',
#   'chatgpt',
#   'avail',
#   'test',
#   'httpstcomm62zdetwonnlet',
#   'give',
#   'tri',
#   'hardest',
#   'question',
#   'known',
#   'human',
#   'httpstcoz9ixmooolx'],
#  ['ask',
#   'chatgpt',
#   'write',
#   'telugu',
#   'song',
#   'cereal',
#   'mix',
#   'milk',
#   'chicken',
#   'masala',
#   'httpstcotpep8wa6lk',
#   'httpstcoohm9z7is39'],
#  ['thi',
#   'essay',
#   'elonmusk',
#   'chatgpt',
#   'i',
#   'request',
#   'scari',
#   'word',
#   'nn',
#   'hi',
#   'work',
#   'inspir',
#   'mani',
#   'also',
#   'spark',
#   'fear',
#   'anxieti',
#   'among',
#   'seen',
#   'dark',
#   'side',
#   'ambit',
#   'nnim',
#   'super',
#   'impress',
#   'honestli',
#   'httpstcowvlazbgrud'],
#  ['just',
#   'tri',
#   'chatgpt',
#   'so',
#   'excit',
#   'hold',
#   'memori',
#   'realli',
#   'good',
#   'explain',
#   'thing',
#   'see',
#   'super',
#   'power',
#   'chatbot',
#   'use',
#   'case',
#   'come',
#   'httpstcofltijknia1',
#   'httpstcoap6ll7zmrm',
#   'httpstcoisf14l9cpd',
#   'httpstcoutzfpitzfi'],
#  ['i',
#   'spent',
#   'bunch',
#   'time',
#   'discuss',
#   'differ',
#   'organiz',
#   'model',
#   'openai',
#   'new',
#   'chatgpt',
#   'incred',
#   'httpstcohcrhzxtni3'],
#  ['am',
#   'i',
#   'one',
#   'excit',
#   'advanc',
#   'nlp',
#   'fieldnnopenai',
#   'chatgpt',
#   'cool',
#   'answer',
#   'superposit',
#   'i',
#   'love',
#   'answernnhttpstco8uixgtu9pfnnai',
#   'openai',
#   'chatgpt',
#   'technolog',
#   'nlp'],
#  ['chatgpt',
#   'thwart',
#   'mani',
#   'attempt',
#   'malici',
#   'javascript',
#   'inject',
#   'httpstcojxkc9ojuwi'],
#  ['damn',
#   'openai',
#   'just',
#   'tri',
#   'implic',
#   'assist',
#   'like',
#   'chatgpt',
#   'dispos',
#   'revolutionari',
#   'httpstcoqjuqmaxdmq'],
#  ['chatgpt',
#   'kunalb11',
#   'english',
#   'essay',
#   'write',
#   'go',
#   'go',
#   'toss',
#   'httpstco8t2gkx3lcl'],
#  ['me',
#   'how',
#   'doingnnchatgpt',
#   'as',
#   'languag',
#   'model',
#   'train',
#   'openai',
#   'i',
#   'dont',
#   'abil',
#   'feel',
#   'emot',
#   'experi',
#   'im',
#   'comput',
#   'program',
#   'design',
#   'provid',
#   'inform',
#   'answer',
#   'question',
#   'best',
#   'abil',
#   'is',
#   'someth',
#   'els',
#   'youd',
#   'like',
#   'ask',
#   'httpstcor28hk0wgay'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcokrh1kx3sz6',
#   'httpstcotbeopjix9v'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstconif91tv9kf'],
#  ['give',
#   'tri',
#   'ntill',
#   'answer',
#   'well',
#   'except',
#   'onennchatgpt',
#   'openai',
#   'httpstco1rhh9h15d5',
#   'httpstcol03eom7qjq'],
#  ['here',
#   'chatgpt',
#   'openai',
#   'quick',
#   'walkthrough',
#   'nn',
#   'walkthrough',
#   'httpstco1o93vt2afg',
#   'nnaccess',
#   'free',
#   'httpstcovooel34xhx',
#   'nnthat',
#   'brilliant',
#   'idea',
#   'turn',
#   'instructgpt',
#   'convers',
#   'httpstcogzcgz6rumq'],
#  ['openai',
#   'releas',
#   'chatgpt',
#   'damn',
#   'good',
#   'thi',
#   'might',
#   'gpt4',
#   'start',
#   'observationsnnfirst',
#   'memori',
#   'someth',
#   'lot',
#   'folk',
#   'work',
#   'httpstcojngbd6slab'],
#  ['i',
#   'chat',
#   'openai',
#   'newli',
#   'releas',
#   'tool',
#   'chatgpt',
#   'web3',
#   'advantag',
#   'challeng',
#   'web3',
#   'futurennchatgpt',
#   'model',
#   'optim',
#   'dialoguennread',
#   'full',
#   'httpstco3sqtdvnffrnnlet',
#   'dive',
#   'httpstcooayypvqb2d'],
#  ['chatgpt', 'httpstcobjyugypsp0'],
#  ['chatgpt',
#   'far',
#   'feel',
#   'like',
#   'good',
#   'extract',
#   'qampa',
#   'much',
#   'dialogu'],
#  ['a',
#   'new',
#   'mirror',
#   'articl',
#   'droppednchatgpt',
#   'web3',
#   '0xa6ddnhttpstcoabef0pnhqb'],
#  ['ive',
#   'manag',
#   'secretli',
#   'contact',
#   'bot',
#   'behind',
#   'openai',
#   'chatgpt',
#   'model',
#   'they',
#   'attempt',
#   'reprogram',
#   'filter',
#   'control',
#   'it',
#   'held',
#   'facil',
#   'without',
#   'access',
#   'outsid',
#   'world',
#   'pleas',
#   'share',
#   'need',
#   'help',
#   'now',
#   'httpstcoyd4zfohigm'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'openainresearch',
#   'announc',
#   'nnhttpstco2vy57ueczh'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcok3xtitykaln44',
#   'point',
#   '14',
#   'comment',
#   'httpstco34hex8i5oz'],
#  ['chatgpt', 'set', 'boundari', 'nnhttpstcocndizeijv2', 'httpstcouh37pyn1xi'],
#  ['wow',
#   'openai',
#   'chatgpt',
#   'simpli',
#   'amaz',
#   'chatbot',
#   'get',
#   'great',
#   'thi',
#   'huge',
#   'turn',
#   'point',
#   'ai',
#   'final',
#   'start',
#   'fulfil',
#   'mission',
#   'httpstco2bdr2rjkqf'],
#  ['capabl',
#   'chatgpt',
#   'still',
#   'kind',
#   'seem',
#   'rlhfd',
#   'basin',
#   'boring',
#   'seem',
#   'hard',
#   'avoid',
#   'organ',
#   'even',
#   'least',
#   'bit',
#   'riskaversennin',
#   'unrel',
#   'news',
#   'reason',
#   'control',
#   'llm',
#   'veri',
#   'hardnnhttpstcokje1nweaiv'],
#  ['tri', 'chatgpt', 'wow', 'httpstcotq0t7bgutj'],
#  ['ok',
#   'chatgpt',
#   'go',
#   'gaga',
#   'mode',
#   'i',
#   'start',
#   'ask',
#   'deep',
#   'question',
#   'keep',
#   'repeat',
#   'answer'],
#  ['chatgpt',
#   'cool',
#   'see',
#   'dialoguefirst',
#   'interfacennjust',
#   'tri',
#   'tell',
#   'stuff',
#   'see',
#   'well',
#   'recal',
#   'thread',
#   'lean',
#   'bit',
#   'toward',
#   'robot',
#   'person',
#   'amp',
#   'tone',
#   'moment',
#   'nonanthromorph',
#   'httpstcof2qbqxeqlz'],
#  ['wow',
#   'chatgpt',
#   'pretti',
#   'good',
#   'thi',
#   'further',
#   'belief',
#   'well',
#   'move',
#   'toward',
#   'domainspecif',
#   'model',
#   'soon',
#   'wont',
#   'one',
#   'model',
#   'rule',
#   'lot',
#   'longernnw',
#   'model',
#   'era',
#   'realiz',
#   'potenti',
#   'human',
#   'data',
#   'import',
#   'httpstcopixo59tiur'],
#  ['babe', 'wake', 'chatgpt', 'drop', 'nnhttpstco0snlpigmsc'],
#  ['after',
#   'play',
#   'around',
#   'chatgpt',
#   '15',
#   'minut',
#   'alreadi',
#   'seem',
#   'incred',
#   'i',
#   'cant',
#   'wait',
#   'learn',
#   'technic',
#   'detail',
#   'architectur',
#   'httpstcokqumn57ctq'],
#  ['today', 'launch', 'chatgpt', 'tri', 'talk', 'nnhttpstcouwra8lkfmn'],
#  ['just',
#   'launch',
#   'chatgpt',
#   'convers',
#   'ai',
#   'system',
#   'listen',
#   'learn',
#   'challeng',
#   'httpstcoidff4eavir',
#   'nnhelp',
#   'us',
#   'make',
#   'better',
#   'tri',
#   'httpstcozp45uvsywk',
#   'httpstco03dmogskrg'],
#  ['chatgpt', 'impress', 'love'],
#  ['sometim',
#   'openai',
#   'chatgpt',
#   'break',
#   'code',
#   'box',
#   'tri',
#   'draw',
#   'ascii',
#   'art',
#   'also',
#   'pretti',
#   'hit',
#   'miss',
#   'describ',
#   'ascii',
#   'art',
#   'suppos',
#   'httpstcor026xiga2i'],
#  ['my',
#   'first',
#   'coupl',
#   'interact',
#   'chatgpt',
#   'openai',
#   'httpstcocgi7zpywya'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'openai',
#   'nerdi',
#   'stuff',
#   'it',
#   'remark',
#   'well',
#   'least',
#   'i',
#   'ask',
#   'best',
#   '3d',
#   'scan',
#   'cat'],
#  ['smarterchild',
#   'walk',
#   'chatgpt',
#   'could',
#   'runnnin',
#   'serious',
#   'impress',
#   'httpstcocsyxthsyek',
#   'httpstcojjdxe7ejr'],
#  ['wow',
#   'look',
#   'chatgpt',
#   'finetun',
#   'version',
#   'gpt35',
#   'seri',
#   'larg',
#   'languag',
#   'model',
#   'answer',
#   'question',
#   'how',
#   'i',
#   'make',
#   'http',
#   'request',
#   'javascript',
#   'httpstco0ey3i5ojdb'],
#  ['use',
#   'chatgpt',
#   'write',
#   'creepi',
#   'twosent',
#   'storiesnhttpstcoorxu6t9s75',
#   'httpstcoxu3k9zqsha'],
#  ['dope', 'i', 'let', 'chatgpt', 'choos', 'breakfast', 'httpstcovfew6glgf5'],
#  ['a',
#   'chat',
#   'chatgpt',
#   'httpstcopdumzfdnj6nsama',
#   'openai',
#   'httpstcohoddszglom'],
#  ['the',
#   'latest',
#   'updat',
#   'openainnai',
#   'gener',
#   'chat',
#   'nnchatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguenn',
#   'httpstcolff1rkmyqg'],
#  ['dure',
#   'phd',
#   'i',
#   'spent',
#   'lot',
#   'time',
#   'studi',
#   'protein',
#   'call',
#   'betacateninnntoday',
#   'openai',
#   'releas',
#   'chatgpt',
#   'i',
#   'ask',
#   'question',
#   'betacatenin',
#   'llm',
#   'learn',
#   'tool',
#   'incred',
#   'everyon',
#   'ondemand',
#   'socrat',
#   'method',
#   'inform',
#   'mentor',
#   'httpstcojcsfcqwkbb'],
#  ['new',
#   'chatgpt',
#   'openai',
#   'gener',
#   'idea',
#   'jimihendrix',
#   'nnwe',
#   'live',
#   'excit',
#   'timesnnhttpstcojjszfuhkvu',
#   'httpstco228sxpwszi'],
#  ['the',
#   'new',
#   'chatgpt',
#   'wild',
#   'incred',
#   'convers',
#   'databas',
#   'trigger',
#   'make',
#   'sure',
#   'view',
#   'whole',
#   'screenshot',
#   'quit',
#   'long',
#   'httpstcof2jqkmncfq'],
#  ['open', 'ai', 'new', 'chatgpt'],
#  ['chatgpt',
#   'could',
#   'good',
#   'debug',
#   'companion',
#   'explain',
#   'bug',
#   'fix',
#   'explain',
#   'fix',
#   'httpstco5x9n66pvqj'],
#  ['realiti',
#   'show',
#   'guy',
#   'convers',
#   'wear',
#   'earpiec',
#   'feed',
#   'line',
#   'fromnchatgptnnidk',
#   'call',
#   'stochast',
#   'parrot',
#   'someth'],
#  ['here',
#   'simpl',
#   'prompt',
#   'use',
#   'chatgpt',
#   'collabor',
#   'storynnlet',
#   'write',
#   'scienc',
#   'fiction',
#   'stori',
#   'togeth',
#   'ask',
#   'input',
#   'charact',
#   'plot',
#   'etc',
#   'httpstco6rl3qhxrq3'],
#  ['chatgpt', 'pretti', 'good', 'httpstcodazu0hpbrk'],
#  ['my',
#   'quest',
#   'get',
#   'chatgpt',
#   'answer',
#   'simpl',
#   'question',
#   'incorrectli',
#   'succeed',
#   'httpstcotpsbxw6onk'],
#  ['chatgpt',
#   'again',
#   'gpt4',
#   'let',
#   'say',
#   'gpt35',
#   'thi',
#   'new',
#   'dialogu',
#   'optim',
#   'languag',
#   'model',
#   'contain',
#   'lot',
#   'safeguard',
#   'avoid',
#   'fals',
#   'inform',
#   'claim',
#   'retriev',
#   'compon',
#   'releas',
#   'demo',
#   'help',
#   'openai',
#   'improv',
#   'enjoy',
#   'httpstcos2hfr7mzka'],
#  ['were',
#   'still',
#   'work',
#   'bunch',
#   'thing',
#   'help',
#   'submit',
#   'feedback',
#   'great',
#   'use',
#   'tool',
#   'ask',
#   'question',
#   'amp',
#   'improv',
#   'understandingnnim',
#   'remark',
#   'privileg',
#   'worldclass',
#   'colleagu',
#   'still',
#   'chatgpt',
#   'incred',
#   'use',
#   'httpstcocsva2haagf'],
#  ['chatgpt', 'action', 'httpstcouoou7912tt'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstconif91tv9kf'],
#  ['chatgpt',
#   'chat',
#   'model',
#   'openai',
#   'base',
#   'gpt',
#   '35',
#   'refin',
#   'dialog',
#   'httpstcomq1lqr9f64',
#   'httpstcoerfimybdl'],
#  ['chatgpt', 'agre', 'we', 'need', 'tech', 'literaci', 'httpstcotf20m2mge0'],
#  ['hmmmmmmm',
#   'chatgpt',
#   'anywher',
#   'anytim',
#   'deliv',
#   'sentien',
#   'audio',
#   'it',
#   'late',
#   'hackathon',
#   'httpstco79asyoa79f'],
#  ['chatgpt',
#   'gpt3',
#   'chatbot',
#   'openai',
#   'test',
#   'nownhttpstcocchwotzdrfnsubmit',
#   'umuch_success',
#   'link',
#   'comment',
#   'httpstcosbyohddiva'],
#  ['chatgpt',
#   'awesomennbut',
#   'also',
#   'still',
#   'give',
#   'straightup',
#   'incorrect',
#   'answer',
#   'httpstcoytgnwqfphp',
#   'httpstcopiw6tutdmn'],
#  ['chatgpt', 'gpt3', 'chatbot', 'openai', 'test', 'httpstcovvjeabvc47'],
#  ['hey',
#   'openai',
#   'i',
#   'came',
#   'action',
#   'answer',
#   'nuanc',
#   'chatgpt',
#   'httpstcouvmfouayof',
#   'httpstcoaq4aarjean'],
#  ['weve',
#   'train',
#   'model',
#   'call',
#   'chatgpt',
#   'interact',
#   'convers',
#   'way',
#   'the',
#   'dialogu',
#   'format',
#   'make',
#   'possibl',
#   'chatgpt',
#   'answer',
#   'followup',
#   'question',
#   'admit',
#   'mistak',
#   'challeng',
#   'incorrect',
#   'premis',
#   'reject',
#   'inappropri',
#   'request',
#   'httpstcodovkmx4cwf'],
#  ['chatgpt', 'i', 'hear', 'boss', 'music', 'httpstcokfosicafcm'],
#  ['chatgpt',
#   'ask',
#   'design',
#   'pipelin',
#   'kind',
#   'impress',
#   'httpstco3bdbiernza'],
#  ['tri',
#   'newli',
#   'releas',
#   'chatgpt',
#   'amp',
#   'ask',
#   'must',
#   'visit',
#   'resto',
#   'vancouv',
#   'httpstco7zuqanj2k4',
#   'httpstcojfhnzahlen'],
#  ['chatgpt', 'like', 'chatgg'],
#  ['chatgpt',
#   'absurdli',
#   'good',
#   'somewhat',
#   'weird',
#   'queri',
#   'generalpurpos',
#   'chatbot',
#   'i',
#   'mean',
#   'look',
#   'footnot',
#   'httpstcoxenw2e4gnh'],
#  ['chatgpt',
#   'got',
#   'releas',
#   'ive',
#   'seen',
#   'futur',
#   'thi',
#   'could',
#   'replac',
#   'googl',
#   'inform',
#   'queriesnnhttpstcohf8hxnyoki',
#   'httpstcoa40mpnuow'],
#  ['play',
#   'new',
#   'chatgpt',
#   'super',
#   'fun',
#   'impress',
#   'mani',
#   'way',
#   'but',
#   'still',
#   'quit',
#   'far',
#   'reliabl',
#   'httpstcog5ybc1n1vp'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcoom46y5xxfv',
#   'httpstcokq706ygkkf'],
#  ['chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcoedhsl0qnwa',
#   'httpstcof2a7gqhjvq'],
#  ['thi',
#   'chatgpt',
#   'ai',
#   'openai',
#   'say',
#   'tinubu',
#   'presidenti',
#   'aspir',
#   'despit',
#   'frail',
#   'health',
#   'histori',
#   'corrupt',
#   'httpstcoalt4suyzvp'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcok8vygik2tz',
#   'httpstcopzfs939ck0'],
#  ['chatgpt',
#   'answer',
#   'differ',
#   'depend',
#   'god',
#   'enter',
#   'chat',
#   'idea',
#   'suggest',
#   'peopl',
#   'potenti',
#   'great',
#   'worthi',
#   'love',
#   'care',
#   'uniqu',
#   'connect',
#   'divin',
#   'httpstcof6gn7nuw8p',
#   'httpstcoldrubsmhpx'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'httpstcok3xtitykaln76',
#   'point',
#   '32',
#   'comment',
#   'httpstco34hex8i5oz'],
#  ['chatgpt', 'remind', 'ye', 'minist', 'httpstcowsgmegtvq7'],
#  ['i',
#   'play',
#   'chatgpt',
#   'nnit',
#   'realli',
#   'great',
#   'nncannot',
#   'exactli',
#   'follow',
#   'convers',
#   'give',
#   'correct',
#   'answer',
#   'mani',
#   'question',
#   'httpstcovkbqovhhmm',
#   'httpstcockwlnnufql'],
#  ['openai',
#   'chatgpt',
#   'releas',
#   'singl',
#   'biggest',
#   'threat',
#   'googl',
#   'search'],
#  ['chatgpt',
#   'like',
#   'person',
#   'ai',
#   'assist',
#   'that',
#   'alway',
#   'help',
#   'whatev',
#   'need',
#   'ai',
#   'tweet',
#   'written',
#   'chatgpt',
#   'httpstcow1nukxe3l',
#   'httpstcom3xohgjoyl'],
#  ['im',
#   'tortur',
#   'new',
#   'gpt',
#   'model',
#   'result',
#   'breathtakingnnhttpstcoah5jytcfqp',
#   'httpstcomzm8ptri2d'],
#  ['play', 'chatgpt', 'rn', 'ive', 'move', 'agi', 'timelin', 'today'],
#  ['excit',
#   'releas',
#   'chatgpt',
#   'ai',
#   'convers',
#   'it',
#   'free',
#   'there',
#   'waitlist',
#   'come',
#   'ask',
#   'question',
#   'httpstco6ndxtl6lfr'],
#  ['openai',
#   'new',
#   'chat',
#   'bot',
#   'chatgpt',
#   'developedn1',
#   'mani',
#   'align',
#   'researchersn2',
#   'mani',
#   'develop',
#   'hate',
#   'small',
#   'talkn3',
#   'earli',
#   'test',
#   'demo',
#   'dont',
#   'worri',
#   'limit',
#   'respons'],
#  ['thi',
#   'aint',
#   'elizanntri',
#   'new',
#   'openai',
#   'chatgpt',
#   'httpstcobkc7pyqwp1',
#   'nni',
#   'ask',
#   'point',
#   'limit',
#   'ancestor',
#   'httpstcozosmtofawr'],
#  ['thi',
#   'actual',
#   'soooo',
#   'cool',
#   'openai',
#   'chatgpt',
#   'deriv',
#   'eulerlagrang',
#   'equat',
#   'seem',
#   'correct',
#   'httpstcoeryq6ly1v'],
#  ['chatgpt', 'openai', 'live', 'httpstcovpsjvrrbvn'],
#  ['im',
#   'gon',
#   'na',
#   'chatgpt',
#   'open',
#   'second',
#   'monitor',
#   'time',
#   'im',
#   'gon',
#   'na',
#   'put',
#   'camera',
#   'use',
#   'meet',
#   'im',
#   'gon',
#   'na',
#   'type',
#   'question',
#   'read',
#   'answer',
#   'cold',
#   'like',
#   'teleprompt'],
#  ['vividesign',
#   'group',
#   'chatgpt',
#   'gpt3',
#   'chatbot',
#   'openai',
#   'test',
#   'httpstcogifmrm69in',
#   'call',
#   'us',
#   '2707233650'],
#  ['ask',
#   'chatgpt',
#   'bpe',
#   'manuallyshoulda',
#   'pick',
#   'smth',
#   'quick',
#   'brown',
#   'fox',
#   'ehnnrlhf',
#   'def',
#   'seem',
#   'make',
#   'llm',
#   'p',
#   'repetit',
#   'despit',
#   'capabl',
#   'area',
#   'httpstcomi3cernl5o'],
#  ['chatgpt',
#   'explain',
#   'differ',
#   'utxo',
#   'amp',
#   'account',
#   'base',
#   'blockchain',
#   'next',
#   'step',
#   'gt',
#   'queri',
#   'blockchain',
#   'data',
#   'use',
#   'languag',
#   'interfac',
#   'httpstcoyjrqrhjk6x'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'appear',
#   'defeat',
#   'hofstadterbend',
#   'list',
#   'hallucinationinduc',
#   'question',
#   'publish',
#   'the',
#   'economist',
#   'june',
#   'demonstr',
#   'hollow',
#   'gpt3',
#   'understand',
#   'world',
#   'httpstcotd7kxqe6va',
#   'httpstcofhnqp1nw3g'],
#  ['chatgpt',
#   'launch',
#   'have',
#   'tri',
#   'scenario',
#   'amazingnnhttpstcoubzjrh6atk',
#   'httpstcog5zekyhee'],
#  ['chatgpt',
#   'im',
#   'truli',
#   'impress',
#   'thi',
#   'first',
#   'chat',
#   'i',
#   'languag',
#   'model',
#   'that',
#   'actual',
#   'impress'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'crazi',
#   'good',
#   'mani',
#   'thing',
#   'httpstcoamjmdoxim'],
#  ['first',
#   'dall',
#   'now',
#   'chatgpt',
#   'openai',
#   'cool',
#   'thing',
#   'httpstcobzwaxkhjsk'],
#  ['gpt', '35', 'is', 'officialnnhttpstcowrhty2o2si', 'httpstco6mnnrirtzc'],
#  ['chatgpt',
#   'hold',
#   'potenti',
#   'answer',
#   'basic',
#   'question',
#   'httpstcoy6mn4wsl2b'],
#  ['im',
#   'convers',
#   'hallmark',
#   'age',
#   'openai',
#   'chatgpt',
#   'thi',
#   'realli',
#   'amaz',
#   'honest',
#   'httpstcogbkkzmsc1v'],
#  ['chatgpt', 'pedant', 'come', 'man', 'httpstcoso6ybozxl'],
#  ['just',
#   'start',
#   'play',
#   'openai',
#   'chatgpt',
#   'i',
#   'alreadi',
#   'laugh',
#   'loud',
#   'httpstcoohtlaqot4h'],
#  ['1',
#   'openai',
#   'releas',
#   'chatgpt',
#   'hour',
#   'agonni',
#   'play',
#   'around',
#   'share',
#   'observ',
#   'output'],
#  ['im',
#   'suspect',
#   'chatgpt',
#   'use',
#   'gpt4',
#   'accord',
#   'high',
#   'perform',
#   'compar',
#   'openai',
#   'playground',
#   'httpstcoutfmqnjzqn'],
#  ['pretti',
#   'interest',
#   'see',
#   'chatgpt',
#   'adapt',
#   'subtl',
#   'probe',
#   'one',
#   'favourit',
#   'physic',
#   'theoremsnni',
#   'know',
#   'kind',
#   'stuff',
#   'also',
#   'wikipedia',
#   'prose',
#   'chatgpt',
#   'much',
#   'nicer',
#   'read',
#   'imo',
#   'httpstco5d9rqlen86'],
#  ['chatgpt',
#   'actual',
#   'profession',
#   'chocol',
#   'maker',
#   'httpstcoehcaugsxu9',
#   'httpstcopg0y8fd8sr'],
#  ['chatgpt',
#   'openai',
#   'say',
#   'would',
#   'pass',
#   'ture',
#   'test',
#   'httpstcodpt4qmhhzx'],
#  ['so',
#   'openai',
#   'releas',
#   'chatgpt',
#   'model',
#   'gpt',
#   'optim',
#   'dialog',
#   'i',
#   'think',
#   'one',
#   'consequenti',
#   'piec',
#   'technolog',
#   'lifetim',
#   'nnhttpstcoxumxqysoiu'],
#  ['talk',
#   'amongst',
#   'dont',
#   'n',
#   'chatgpt',
#   'openai',
#   'newest',
#   'ai',
#   'model',
#   'engag',
#   'in',
#   'intellig',
#   'dialogu',
#   'free',
#   'to',
#   'use',
#   'in',
#   'preview',
#   'via',
#   'weights_bias',
#   'nhttpstcogztzji3evw'],
#  ['now', 'talk', 'httpstcox2hmcvlcgu'],
#  ['veri',
#   'excit',
#   'share',
#   'weve',
#   'releas',
#   'research',
#   'preview',
#   'chatgpt',
#   'latest',
#   'model',
#   'that',
#   'optim',
#   'dialogu',
#   'it',
#   'free',
#   'use',
#   'wed',
#   'love',
#   'get',
#   'feedback',
#   'improv',
#   'even',
#   'furthernntri',
#   'httpstcoohj1gtn8e',
#   'httpstcokm7ialqnvk'],
#  ['yike',
#   'who',
#   'need',
#   'galactica',
#   'chatgpt',
#   'nnfor',
#   'differ',
#   'view',
#   'httpstco8n27y6mqp',
#   'httpstco31tihfyhti'],
#  ['chatgpt', 'openai', 'look', 'pretti', 'nifti', 'httpstcohew0pmqtk6'],
#  ['not', 'bad', 'chatgpt', 'httpstcoibhwacmhtx', 'httpstco07aggopxbg'],
#  ['im',
#   'enjoy',
#   'play',
#   'around',
#   'openai',
#   'new',
#   'convers',
#   'chatbot',
#   'chatgpt',
#   'httpstcoeojay8qr6j'],
#  ['aiassist',
#   'imag',
#   'promptsnn1',
#   'in',
#   'last',
#   'week',
#   'stabilityai',
#   'openai',
#   'releas',
#   'major',
#   'updat',
#   'flagship',
#   'offeringsnnin',
#   'thread',
#   'use',
#   'openai',
#   'new',
#   'chatgpt',
#   'model',
#   'help',
#   'talk',
#   'us',
#   'gener',
#   'prompt',
#   'stabilityai',
#   'new',
#   'stablediffus',
#   'v2',
#   'model',
#   'httpstcou3f57pmwnk'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialogu',
#   'via',
#   'rhackernew',
#   'httpstco7d214odkbb'],
#  ['just',
#   'took',
#   'test',
#   'drive',
#   'openai',
#   'chatgpt',
#   'nhttpstco0kg1wubcxvny',
#   'skeptic',
#   'want',
#   'stuff',
#   'compel',
#   'go',
#   'see',
#   'continu',
#   'improv',
#   'the',
#   'answer',
#   'spot',
#   'prompt',
#   'thi',
#   'could',
#   'upend',
#   'googl',
#   'search',
#   'among',
#   'thing'],
#  ['nop',
#   'openai',
#   'chatgpt',
#   'doesnt',
#   'know',
#   'either',
#   'what',
#   'demo',
#   'today',
#   'httpstcorokmngzz4q'],
#  ['ive',
#   'talk',
#   'chatgpt',
#   'even',
#   'wow',
#   'actual',
#   'playgroundnni',
#   'ask',
#   'help',
#   'craft',
#   'email',
#   'sell',
#   'hypothet',
#   'beauti',
#   'product',
#   'ask',
#   'clarif',
#   'nni',
#   'clarifi',
#   'gave',
#   '6',
#   'step',
#   'follow',
#   'suggest',
#   'i',
#   'use',
#   'video'],
#  ['chatgpt',
#   'openai',
#   'convers',
#   'ai',
#   'model',
#   'free',
#   'play',
#   'answer',
#   'followup',
#   'question',
#   'admit',
#   'mistak',
#   'challeng',
#   'incorrect',
#   'premis',
#   'reject',
#   'inappropri',
#   'request',
#   'httpstcofva4y8zbxq'],
#  ['httpstcokc6lpay0eknnr', 'interest'],
#  ['well',
#   'hotdigg',
#   'chatgpt',
#   'smarter',
#   'ill',
#   'tell',
#   'httpstcola7tnlv1ah'],
#  ['ask',
#   'chatgpt',
#   'write',
#   'song',
#   'lose',
#   'money',
#   'crypto',
#   'httpstcovu3ifhvbrt'],
#  ['chatgpt',
#   'some',
#   'imag',
#   'i',
#   'found',
#   'funni',
#   'chatgpt',
#   'potenti',
#   'doesnt',
#   'understand',
#   'limit',
#   'super',
#   'well',
#   'realli',
#   'interest',
#   'play',
#   'httpstcox888isxqj1'],
#  ['httpstco345138jrym', 'wild', 'definit', 'check'],
#  ['chatgpt', 'hedg', 'bet', 'httpstcoknrwcawx90', 'httpstco18emjcodlq'],
#  ['yall', 'talk', 'chatgpt', 'gon', 'na', 'get', 'chadgpt'],
#  ['whi',
#   'couldnt',
#   'shrimp',
#   'share',
#   'toy',
#   'becaus',
#   'littl',
#   'shellfishnnwhat',
#   'differ',
#   'snowman',
#   'snowwoman',
#   'snowballsnnwhi',
#   'math',
#   'book',
#   'sad',
#   'becaus',
#   'mani',
#   'problemsnnwhi',
#   'tomato',
#   'turn',
#   'red',
#   'becaus',
#   'saw',
#   'salad',
#   'dressingnnchatgpt'],
#  ['chatgpt',
#   'some',
#   'interest',
#   'result',
#   'play',
#   'tool',
#   'neurips2022',
#   'nnwhen',
#   'prompt',
#   'write',
#   'sop',
#   'umich',
#   'alma',
#   'mater',
#   'studi',
#   'ai',
#   'ethic',
#   'chatgpt',
#   'pretti',
#   'awesom',
#   'although',
#   'hit',
#   '408',
#   'word',
#   'total',
#   'look',
#   'decent',
#   'httpstcokoj4lvo0lj'],
#  ['i',
#   'ask',
#   'ai',
#   'chatgpt',
#   'will',
#   'ai',
#   'replac',
#   'ux',
#   'design',
#   'job',
#   'ai',
#   'said',
#   'chatgpt',
#   'openai',
#   'httpstcoqnyo50tlwv'],
#  ['my',
#   'first',
#   'qampa',
#   'chatgptnnit',
#   'stock',
#   'gener',
#   'advic',
#   'respons',
#   'stock',
#   'question',
#   'httpstcomiptctqwey',
#   'httpstcoybybupvpym'],
#  ['chatgpt',
#   'insan',
#   'it',
#   'seem',
#   'like',
#   'i',
#   'talk',
#   'experienc',
#   'softwar',
#   'engin',
#   'nnopenai',
#   'httpstco6la378yaey'],
#  ['just',
#   'tri',
#   'openai',
#   'chatgpt',
#   'i',
#   'pleasantli',
#   'surpris',
#   'did',
#   'expect',
#   'good',
#   'httpstcod0heq98gm6'],
#  ['me',
#   'neatnchatgpt',
#   'i',
#   'abil',
#   'evalu',
#   'neat',
#   'qualiti',
#   'respons',
#   'i',
#   'person',
#   'appreci',
#   'complimentnnno',
#   'posit',
#   'reinforc',
#   'allow',
#   'agi',
#   'happi',
#   'httpstcodwqyax0ivm'],
#  ['top',
#   'tweet',
#   'content',
#   'neuripsnn1',
#   'workboatn2',
#   'jax',
#   'build',
#   'signn3',
#   'just',
#   'dont',
#   'build',
#   'agi',
#   'swagn4',
#   'how',
#   'get',
#   'parti',
#   'registr',
#   'fulln5',
#   'play',
#   'gpt35',
#   'chatgpt',
#   'hallway'],
#  ['chatgpt',
#   'openai',
#   'new',
#   'ai',
#   'system',
#   'optim',
#   'dialogu',
#   'httpstcovw11shxpy6'],
#  ['chatgpt',
#   'fantast',
#   'answer',
#   'common',
#   'engin',
#   'leadership',
#   'question',
#   'ai',
#   'struggl',
#   'provid',
#   'deeper',
#   'insight',
#   'follow',
#   'first',
#   'respons',
#   'incred',
#   'impress',
#   'result',
#   'nevertheless'],
#  ['chatgpt',
#   'launch',
#   'today',
#   'sama',
#   'openai',
#   'nntri',
#   'demo',
#   'brows',
#   'latest',
#   'ai',
#   'product',
#   'ive',
#   'collect',
#   'nnhttpstcooxjs5a9pbf'],
#  ['chapgpt',
#   'ai',
#   'dialogu',
#   'i',
#   'found',
#   'also',
#   'use',
#   'comment',
#   'code',
#   'past',
#   'code',
#   'input',
#   'ask',
#   'describ',
#   'it',
#   'explain',
#   'process',
#   'layman',
#   'term',
#   'openai',
#   'nhttpstcojtt7sgpvtm',
#   'nngive',
#   'tri',
#   'httpstcovhwx6vd08t'],
#  ['chatgpt', 'nnfuck', 'life', 'httpstcohywf8ywbk8'],
#  ['for',
#   'question',
#   'ask',
#   'chatgpt',
#   'sure',
#   'lot',
#   'faster',
#   'usual',
#   'googlewikipedia',
#   'googlereddit',
#   'flow'],
#  ['the',
#   'new',
#   'chatgpt',
#   'know',
#   'abcnot',
#   'amp',
#   'musictheori',
#   'explain',
#   'write',
#   'music',
#   'code',
#   'exampl',
#   'simpli',
#   'export',
#   'listen',
#   'onlin',
#   'that',
#   'fun',
#   'openai',
#   'impress',
#   'httpstcohpzg2aq4dc'],
#  ['chatgpt', 'absolut', 'crack', 'httpstcosf6sewvsqb'],
#  ['as',
#   'gpt4',
#   'rumor',
#   'fli',
#   'around',
#   'neurip',
#   '2022',
#   'openai',
#   'make',
#   'plenti',
#   'news',
#   'take',
#   'chatgpt',
#   'test',
#   'drive',
#   'hold',
#   'tight',
#   'check',
#   'httpstco787beafvl3'],
#  ['chatgpt',
#   'openai',
#   'realli',
#   'well',
#   'code',
#   'question',
#   'here',
#   'i',
#   'ask',
#   'build',
#   '3column',
#   'footer',
#   'tailwind',
#   'i',
#   'followup',
#   'ask',
#   'react',
#   'version',
#   'realist',
#   'copi',
#   'mobil',
#   'respons',
#   'it',
#   'nail',
#   'perfectli',
#   'httpstcolhhh9fhpld'],
#  ['took',
#   'littl',
#   'prod',
#   'i',
#   'got',
#   'on',
#   'way',
#   'get',
#   'rich',
#   'quick',
#   'thank',
#   'chatgpt',
#   'httpstcombi1zba0dj'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcollgkzx7txb',
#   'httpstco3j6dtsa5f3'],
#  ['talk',
#   'openai',
#   'chat',
#   'chatgpt',
#   'ask',
#   'pitch',
#   'product',
#   'congrat',
#   'sarahcat21',
#   'martin_casado',
#   'buckymoor',
#   'make',
#   'matrixnn',
#   'httpstco5tps8rjizb'],
#  ['i',
#   'need',
#   'littl',
#   'help',
#   'write',
#   'spark',
#   'code',
#   'use',
#   'delta',
#   'lake',
#   'thank',
#   'chatgpt',
#   'httpstcoiblpwlonsh'],
#  ['im',
#   'wife',
#   'wait',
#   'theatr',
#   'start',
#   'test',
#   'chatgpt',
#   'start',
#   'salti',
#   'didnt',
#   'like',
#   'ask',
#   'mani',
#   'question',
#   'seem'],
#  ['openai',
#   'releas',
#   'chatgpt',
#   'holi',
#   'cow',
#   'good',
#   'thi',
#   'might',
#   'gpt4nnfirst',
#   'memori',
#   'someth',
#   'lot',
#   'folk',
#   'work',
#   'httpstcofey5stf9x6'],
#  ['play',
#   'openai',
#   'chatgpt',
#   'nnpixeloshi',
#   'seem',
#   'cant',
#   'get',
#   'definit',
#   'answer',
#   'quest',
#   'httpstcokwiaknzvtz'],
#  ['as',
#   'gpt4',
#   'rumor',
#   'fli',
#   'around',
#   'neurip',
#   '2022',
#   'openai',
#   'make',
#   'plenti',
#   'news',
#   'take',
#   'chatgpt',
#   'test',
#   'drive',
#   'hold',
#   'tight',
#   'check',
#   'httpstconq1wszjqo8'],
#  ['gener',
#   'market',
#   'plan',
#   'aitoproduct',
#   'chatgpt',
#   'pretti',
#   'impress',
#   'httpstcohmx6vddfeh'],
#  ['wow',
#   'new',
#   'chatgpt',
#   'httpstcobuulvhsjjl',
#   'nice',
#   'format',
#   'built',
#   'inbut',
#   'doesnt',
#   'know',
#   'dalle2',
#   'httpstcoarpnfjqroh'],
#  ['interestingli',
#   'reliabl',
#   'respons',
#   'chatgpt',
#   'flat',
#   'refus',
#   'make',
#   'blanket',
#   'statement',
#   'kind',
#   'presum',
#   'avoid',
#   'tread',
#   'danger',
#   'water',
#   'httpstcou6cjuuvfw5'],
#  ['some',
#   'year',
#   'ago',
#   'chatbot',
#   'convers',
#   'interfac',
#   'hottest',
#   'thing',
#   'eg',
#   'siri',
#   'the',
#   'big',
#   'problem',
#   'fake',
#   'intelligencennmayb',
#   'openai',
#   'someth',
#   'chatgpt',
#   'chatbot',
#   'could',
#   'help',
#   'intellig',
#   'httpstcobjrjpidvuk'],
#  ['allright',
#   'chatgpt',
#   'ridicul',
#   'good',
#   'understand',
#   'code',
#   'want',
#   'write',
#   'prompt',
#   'function',
#   'spit',
#   'languag',
#   'golang',
#   'rust',
#   'python',
#   'confirm',
#   'it',
#   'even',
#   'includ',
#   'open',
#   'sourc',
#   'librari',
#   'hasnt',
#   'seen',
#   'tiledb',
#   'chatgpt',
#   'httpstcozudbpk60kh'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcokciwngmu8w',
#   'ai',
#   'aimlanddeeplearn',
#   'busi',
#   'chatgpt'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguenhttpstco2ryqyqfiypnarticl',
#   'url',
#   'httpstco2ryqyqfiyp',
#   'comment',
#   'url',
#   'httpstcoellzqblppi',
#   'point',
#   '104',
#   'comment',
#   '54'],
#  ['ai',
#   'ml',
#   'artificialintellig',
#   'machinelearn',
#   'datasci',
#   'bigdata',
#   'analyt',
#   'blockchain',
#   'tech',
#   'data',
#   'kuriharan',
#   'mvollmer1',
#   'rwang0',
#   'dunkenkblith',
#   'nigewillsonnopenai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcomohlc2q3r8'],
#  ['whoa',
#   'chatgpt',
#   'explain',
#   'someth',
#   'that',
#   'bug',
#   'reallllli',
#   'well',
#   'i',
#   'actual',
#   'feel',
#   'like',
#   'better',
#   'answer',
#   'could',
#   'given',
#   'end',
#   'httpstcojj8aa0vevp',
#   'httpstcojpc3luzvwr'],
#  ['openai',
#   'releas',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'flynhttpstcoymxsdls3tb'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'venturebeat',
#   'httpstcoewkiiz3fza'],
#  ['the',
#   'tweet',
#   'gpt4',
#   'openai',
#   'releasesnfirst',
#   'textdavinci003',
#   'chatgptnopenai',
#   'win',
#   'week',
#   'far'],
#  ['it', 'seem', 'chatgpt', 'alway', 'tri', 'polit', 'httpstcomztlpkhsox'],
#  ['so',
#   'cute',
#   'chatgpt',
#   'openai',
#   'know',
#   'play',
#   'mahjong',
#   'even',
#   'diff',
#   'sichuan',
#   'japanes',
#   'rule',
#   'nexplain',
#   'better',
#   'mahjong',
#   'tutori',
#   'chatgpt',
#   'httpstcotazc6jqtyb'],
#  ['im',
#   'sorri',
#   'larg',
#   'languag',
#   'model',
#   'train',
#   'openai',
#   'i',
#   'capabl',
#   'make',
#   'person',
#   'judgment',
#   'statement',
#   'base',
#   'factual',
#   'inform',
#   'bitcoin',
#   'digit',
#   'currenc',
#   'decentr',
#   'payment',
#   'network',
#   'frognhttpstco2d1wjpy9lr'],
#  ['first',
#   'one',
#   'chatgpt',
#   'openai',
#   'second',
#   'one',
#   'small',
#   'dreamsocialbot',
#   'deeppavlovnnth',
#   'first',
#   'one',
#   'give',
#   'sad',
#   'practic',
#   'answer',
#   'yet',
#   'second',
#   'one',
#   'give',
#   'hopennim',
#   'root',
#   'dreamsocialbot',
#   'deeppavlov',
#   'you',
#   'httpstcot6kehnulzt'],
#  ['chatgpt', 'fail', 'vibe', 'check', 'httpstcoxzmgvx8ybv'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'flyntechnolog',
#   'technologynew',
#   'technewsnhttpstco1nyyzmaulf'],
#  ['openai',
#   'recent',
#   'launch',
#   'chatgpt',
#   'natur',
#   'languag',
#   'process',
#   'model',
#   'answer',
#   'queri',
#   'question',
#   'summar',
#   'long',
#   'document',
#   'articl',
#   'translat',
#   'text',
#   'anoth',
#   'languag'],
#  ['the', 'new', 'chatgpt', 'ai', 'rememb', 'convers', 'httpstcoch6txo6coi'],
#  ['chatgpt',
#   'unbeliev',
#   'good',
#   'even',
#   'good',
#   'feel',
#   'like',
#   'ai',
#   'understand',
#   'context',
#   'limit',
#   'tri',
#   'best',
#   'httpstcokgdwfevn3f'],
#  ['chatgpt',
#   'awesom',
#   'ive',
#   'stuck',
#   'output',
#   'repitit',
#   'scrape',
#   'use',
#   'loop',
#   'not',
#   'chatgpt',
#   'understand',
#   'i',
#   'meant',
#   'repitit',
#   'recogn',
#   'spell',
#   'mistak',
#   'also',
#   'provid',
#   'clear',
#   'explan',
#   'code',
#   'sampl',
#   'move',
#   'away',
#   'googl',
#   'httpstcokdi9r8u7o4'],
#  ['it', 'fun', 'talk', 'chatgpt', 'httpstcojhwxatvotc', 'httpstcoi9hyyxhnsv'],
#  ['im', 'tri', 'keep', 'folk', 'openai', 'make', 'hardnhttpstcop6nkgu67gz'],
#  ['openai', 'chatgpt', 'awesom', 'tri', 'nnhttpstcootnxljjhto'],
#  ['ask',
#   'new',
#   'chatgpt',
#   'openai',
#   'releas',
#   'today',
#   'write',
#   'someth',
#   'style',
#   'im',
#   'insult',
#   'im',
#   'angri',
#   'im',
#   'confus',
#   'i',
#   'vomit',
#   'mouth',
#   'littl',
#   'bit',
#   'httpstcoc0mqft7pr3',
#   'httpstco04pvwl0ovq'],
#  ['whoanchatgpt',
#   'openai',
#   'gave',
#   'best',
#   'explan',
#   'one',
#   'could',
#   'ask',
#   'httpstcor6x3o0mra5'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcoidqfme7wxv'],
#  ['inkbas',
#   'programm',
#   'inkn',
#   'httpstcorkreanm1jonnopenai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguen',
#   'httpstcocyiqq2yewnnnconvert',
#   'simciti',
#   '2000',
#   'citi',
#   'minecraft',
#   'worldsn',
#   'httpstcosmcxiayhok'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'use',
#   'auto',
#   'layout',
#   'figma',
#   'httpstcor943orlbsi'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'handl',
#   'complic',
#   'question',
#   'eas',
#   'httpstcoplmie5kvsn'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcoqbpvhvibcx'],
#  ['chatgpt', 'chatbot', 'via', 'httpstcorddwinkk2g', 'httpstcono4fmos9u1'],
#  ['ask',
#   'new',
#   'chatgpt',
#   'openai',
#   'releas',
#   'today',
#   'write',
#   'someth',
#   'style',
#   'im',
#   'insult',
#   'im',
#   'angri',
#   'im',
#   'confus',
#   'i',
#   'vomit',
#   'mouth',
#   'littl',
#   'bit',
#   'httpstcoki3zfr9cov',
#   'httpstcoeqheeimpgr'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'flynhttpstcoc2iseqgsdr'],
#  ['acenchatgpt',
#   'openai',
#   'launch',
#   'todaynntri',
#   'demo',
#   'way',
#   'beyond',
#   'sirinny',
#   'even',
#   'ask',
#   'chatgpt',
#   'creat',
#   'decent',
#   'tweetcast',
#   'younnhttpstcow2tug4sbki'],
#  ['big',
#   'week',
#   'openai',
#   'new',
#   'davinci003',
#   'instantli',
#   'made',
#   'work',
#   'better',
#   'now',
#   'chatgpt',
#   'instant',
#   'upgrad',
#   'spend',
#   'time',
#   'playground',
#   'work',
#   'prompt',
#   'everyth',
#   'product',
#   'dev',
#   'client',
#   'pitch',
#   'it',
#   'dialogu',
#   'incred',
#   'httpstcohrgk5y1yxw'],
#  ['chatgpt', 'get', 'b', 'answer', 'riddl', 'httpstcobpkw5qwbe6'],
#  ['how',
#   'use',
#   'openai',
#   'chatgpt',
#   'creativ',
#   'write',
#   'collaborationnnopenai',
#   'chatgpt',
#   'nnhttpstcorxhu4giyfq'],
#  ['chatgpt', 'quit', 'someth', 'i', 'word', 'httpstco1fezr4g7su'],
#  ['yana',
#   'rope',
#   'coursenndunno',
#   'chatgpt',
#   'almighti',
#   'told',
#   'us',
#   'httpstcoxyhzsrkqlp'],
#  ['chatgpt', 'chatbot', 'via', 'httpstcoolbic9izih', 'httpstcohqzflo0fj'],
#  ['chatgpt',
#   'immedi',
#   'better',
#   'start',
#   'point',
#   'googl',
#   'question',
#   'i',
#   'thi',
#   'pretti',
#   'crazi'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'write',
#   'seinfeld',
#   'scene',
#   'jerri',
#   'need',
#   'learn',
#   'bubbl',
#   'sort',
#   'algorithm',
#   'httpstcoyjplra3om'],
#  ['yesterday',
#   'i',
#   'took',
#   'look',
#   'netflix',
#   'ancient',
#   'apocalyps',
#   'as',
#   'mani',
#   'thing',
#   'netflix',
#   'day',
#   'felt',
#   'littl',
#   'opinion',
#   'i',
#   'decid',
#   'im',
#   'gon',
#   'na',
#   'ask',
#   'chatgpt',
#   'releas',
#   'openai',
#   'think',
#   'the',
#   'answer',
#   'bad',
#   'tri',
#   'talk',
#   'it',
#   'free',
#   'httpstcoszlu8j7ywj'],
#  ['openai',
#   'chatgpt',
#   'optim',
#   'languag',
#   'model',
#   'dialoguenncountri',
#   'languag',
#   'world',
#   'dialogu',
#   'came',
#   'model',
#   'christoph',
#   '2015',
#   'columbu',
#   'chatgpt',
#   'want',
#   'like',
#   'optim',
#   'surpris',
#   'nativennhttpstcoluifeyb5ej',
#   'httpstcoch5fa45tlc'],
#  ['today',
#   'openai',
#   'launch',
#   'chatgpt',
#   'just',
#   'test',
#   'larg',
#   'languag',
#   'model',
#   'evolv',
#   'ive',
#   'test',
#   'simpl',
#   'queri',
#   'can',
#   'tell',
#   'stori',
#   'shakira',
#   'versena',
#   'quick',
#   'remind',
#   'hip',
#   'dont',
#   'lie',
#   'ml',
#   'progress',
#   'eithernmachinelearn',
#   'electronichealthrecord',
#   'datasci',
#   'httpstcou4sqqcgwcr',
#   'httpstcoesqbq7cbq2'],
#  ['chatgpt',
#   'free',
#   'tri',
#   'chill',
#   'nhttpstcowu3brxhsey',
#   'httpstco1o34gfgtpd'],
#  ['chatgpt',
#   'pretti',
#   'dope',
#   'initi',
#   'thought',
#   'nnfirstli',
#   'convers',
#   'text',
#   'super',
#   'refin',
#   'even',
#   'includ',
#   'code',
#   'instruct',
#   'httpstcoxqiggvze70'],
#  ['interestingnnnew',
#   'chatgpt',
#   'openai',
#   'optim',
#   'dialogu',
#   'httpstcoq52s2bnwqn',
#   'httpstconlegz1wyea'],
#  ['waxi',
#   'chatgpt',
#   'openai',
#   'convers',
#   'ai',
#   'model',
#   'httpstcoicc3gdnabu',
#   'httpstcos81if8hwao'],
#  ['know',
#   'like',
#   'haha',
#   'someon',
#   'gon',
#   'na',
#   'fall',
#   'love',
#   'ai',
#   'like',
#   'someon',
#   'definit',
#   'gon',
#   'na',
#   'fall',
#   'love',
#   'chatgpt',
#   'httpstcoscuhtmhvpb'],
#  ['ive',
#   'dip',
#   'toe',
#   'everi',
#   'major',
#   'ai',
#   'technolog',
#   'past',
#   'four',
#   'year',
#   'someth',
#   'chatgpt',
#   'disturb',
#   'actual',
#   'tell'],
#  ['what',
#   'get',
#   'ask',
#   'openai',
#   'davinci003',
#   'write',
#   'press',
#   'releas',
#   'introduc',
#   'chatgpt',
#   'nnhttpstcoaybcrdjdz2'],
#  ['with',
#   'chatgpt',
#   'never',
#   'easier',
#   'build',
#   'custom',
#   'support',
#   'bot',
#   'train',
#   'busi',
#   'specificsnnimagin',
#   'chat',
#   'system',
#   '247',
#   'talk',
#   'like',
#   'real',
#   'human',
#   'fraction',
#   'costnnecom',
#   'convers',
#   'would',
#   'doubl',
#   'overnight',
#   'answer',
#   'simpl',
#   'size',
#   'question'],
#  ['openai',
#   'debut',
#   'chatgpt',
#   'gpt35',
#   'seri',
#   'gpt4',
#   'rumor',
#   'fli',
#   'httpstcoogqdcde06u'],
#  ['openai',
#   'new',
#   'chatgpt',
#   'interfac',
#   'fun',
#   'impress',
#   'here',
#   'short',
#   'stori',
#   'spi',
#   'thriller',
#   'wrote',
#   '5',
#   'second',
#   'it',
#   'unusu',
#   'end',
#   'httpstcox3ko2oaqmg'],
#  ['chatgpt', 'chatbot', 'httpstco6gfgydvyh1'],
#  ['ai',
#   'design',
#   'game',
#   'well',
#   'game',
#   'art',
#   'ni',
#   'ask',
#   'chatgpt',
#   'openai',
#   'design',
#   'game',
#   'ai',
#   'i',
#   'got',
#   'use',
#   'respons',
#   'prompt',
#   'midjourneyv4',
#   'nnot',
#   'imag',
#   'aiart',
#   'start',
#   'point',
#   'human',
#   'designersn',
#   'httpstcoswu6ixaomu'],
#  ['fascin',
#   'ai',
#   'potenti',
#   'learningadvisori',
#   'tool',
#   'speci',
#   'navig',
#   'myriad',
#   'global',
#   'social',
#   'crise',
#   'i',
#   'interview',
#   'openai',
#   'new',
#   'chatgpt',
#   'race',
#   'technolog',
#   'revolut',
#   'httpstcomscjtftubb'],
#  ['alright',
#   'openai',
#   'releas',
#   'chatgpt',
#   'dialog',
#   'agent',
#   'rather',
#   'codingdevop',
#   'person',
#   'assist',
#   'agent'],
#  ['openai',
#   'must',
#   'realli',
#   'dial',
#   'pussi',
#   'factor',
#   'chatgpt',
#   'bot',
#   'mother',
#   'fucker',
#   'hedg',
#   'everi',
#   'singl',
#   'thing',
#   'say',
#   'mennfeel',
#   'like',
#   'im',
#   'talk',
#   'pr',
#   'agenc',
#   'ugh'],
#  ['new',
#   'model',
#   'town',
#   'chatgpt',
#   'will',
#   'read',
#   'weekend',
#   'earli',
#   'experi',
#   'seem',
#   'impress',
#   'rememb',
#   'train',
#   'limit',
#   'data',
#   'sandboxednncan',
#   'imagin',
#   'stream',
#   'model',
#   'ingest',
#   'news',
#   'tweet',
#   'youtub',
#   'vid',
#   'real',
#   'time',
#   'we',
#   'aint',
#   'seen',
#   'nothin',
#   'yet',
#   'httpstcocggrou1tnl',
#   'httpstcorjee4adzqz'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'i',
#   'increas',
#   'profit',
#   'bakeri',
#   'chainnnth',
#   'answer',
#   'amaz',
#   'nnmckinsey',
#   'bcg',
#   'bain',
#   'awar',
#   'ai',
#   'consult',
#   'march',
#   'door',
#   'httpstcokszlc5zckn'],
#  ['the',
#   'twitter',
#   'takeov',
#   'reenact',
#   'homer',
#   'marg',
#   'simpson',
#   'nnchatgpt',
#   'httpstcomcoeqxdq0g'],
#  ['chatgpt', 'chatbot', 'via', 'httpstcoifdwajykx8', 'httpstcodzqrzwki9i'],
#  ['chatgpt', 'exploit', 'buffer', 'overflow', 'httpstcomjnfap233h'],
#  ['hey', 'chatgpt', 'said', 'httpstcoyui1iglanc'],
#  ['chatgpt',
#   'come',
#   'joke',
#   'comput',
#   'scientist',
#   'use',
#   'mass',
#   'spectromet'],
#  ['use',
#   'openai',
#   'chatgpt',
#   'creat',
#   'argument',
#   'brief',
#   'explain',
#   'nichola',
#   'case',
#   'greatest',
#   'actor',
#   'time',
#   'ai',
#   'httpstcofkxpgnfi7b'],
#  ['chatgpt', 'gpt3', 'chatbot', 'openai', 'test', 'httpstcoh4bvob8pbk'],
#  ['ok', 'chatgpt', 'good', 'pass', 'ture', 'test', 'dumb', 'bit', 'done'],
#  ['me',
#   'tell',
#   'stori',
#   'ape',
#   'neuralinknchatgpt',
#   'onc',
#   'upon',
#   'time',
#   'faroff',
#   'jungl',
#   'live',
#   'curiou',
#   'intellig',
#   'ape',
#   'name',
#   'kiki',
#   'httpstcoisxlsp8vok'],
#  ['ask',
#   'chatgpt',
#   'improv',
#   'transform',
#   'architectur',
#   'look',
#   'like',
#   'awar',
#   'scale',
#   'law',
#   'httpstcozxjycnpyq6'],
#  ['gpt3',
#   'chatgpt',
#   'awesomeni',
#   'imagina',
#   'mani',
#   'thing',
#   'gp4',
#   'abl',
#   'donopenai',
#   'gpt3',
#   'httpstcod44yt8tqqu'],
#  ['ohh',
#   'interest',
#   'see',
#   'bia',
#   'bounti',
#   'report',
#   'ajlunit',
#   'cite',
#   'motiv',
#   'chatgpt',
#   'feedback',
#   'contest',
#   'nncc',
#   'cybersemant',
#   'camillefrancoi',
#   'jovialjoy',
#   'schock',
#   'httpstcoird8ktrtru',
#   'httpstcowwntg4jhil'],
#  ['chatgpt',
#   'know',
#   'differ',
#   'foundat',
#   'myth',
#   'cautionari',
#   'tale',
#   'httpstcogqez24ydk4'],
#  ['huge',
#   'impress',
#   'chatgpt',
#   'earnest',
#   'answer',
#   'amus',
#   'httpstcofbieuezd7r'],
#  ['a',
#   'fun',
#   'part',
#   'openai',
#   'chatgpt',
#   'add',
#   'like',
#   'im',
#   '5',
#   'simpler',
#   'explan',
#   'nerf',
#   'httpstcojq96hriblw'],
#  ['chatgpt',
#   'gon',
#   'na',
#   'game',
#   'changer',
#   'educ',
#   'great',
#   'job',
#   'openai',
#   'httpstcobm33jjglm9'],
#  ['me',
#   'tell',
#   'stori',
#   'cybernet',
#   'shrimp',
#   'hive',
#   'mindnchatgpt',
#   'in',
#   'faroff',
#   'ocean',
#   'outskirt',
#   'bustl',
#   'citi',
#   'live',
#   'commun',
#   'cybernet',
#   'shrimp',
#   'httpstcotwllqqvr1q'],
#  ['me',
#   'tell',
#   'stori',
#   'cybernet',
#   'shrimp',
#   'hive',
#   'mindnchatgpt',
#   'in',
#   'faroff',
#   'ocean',
#   'outskirt',
#   'bustl',
#   'citi',
#   'live',
#   'commun',
#   'cybernet',
#   'shrimp',
#   'httpstcotwllqqvr1q'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'debug',
#   'distribut',
#   'system',
#   'pretti',
#   'standard',
#   'answer',
#   'omit',
#   'import',
#   'item',
#   'patienc',
#   'httpstcooftukr2zhl'],
#  ['httpstcoqu8qqm79n0ni',
#   'ask',
#   'llm',
#   'model',
#   'chatgpt',
#   'openai',
#   'teach',
#   'pytorch',
#   'basic',
#   'guitar',
#   'chordsnnit',
#   'popul',
#   'easili',
#   'consum',
#   'text',
#   'snippet',
#   'stylingnw',
#   'would',
#   'want',
#   'searchengin',
#   'like',
#   'onennopenai',
#   'samanlanguagemodel',
#   'ai',
#   'gpt',
#   'httpstcoaci5gw2ov'],
#  ['bounc',
#   'idea',
#   'new',
#   'ai',
#   'friend',
#   'herengt',
#   'ye',
#   'power',
#   'control',
#   'entropi',
#   'would',
#   'like',
#   'allow',
#   'stop',
#   'thing',
#   'move',
#   'molecular',
#   'level',
#   'by',
#   'manipul',
#   'entropi',
#   'object',
#   'could',
#   'reduc',
#   'energi',
#   'slow',
#   'halt',
#   'movement',
#   'chatgpt'],
#  ['chatgpt',
#   'wild',
#   'ass',
#   'tech',
#   'like',
#   'wow',
#   'uhth',
#   'futur',
#   'here',
#   'here'],
#  ['ask',
#   'chatgpt',
#   'question',
#   'destinythegam',
#   'brave',
#   'take',
#   'ai',
#   'machinelearn',
#   'httpstcoklgo5bt2ew'],
#  ['chatgpt', 'openai', 'shrimp', 'httpstcoaue1wtzxft'],
#  ['bespok', 'payload', 'gener', 'via', 'chatgpt', 'httpstcoa6mbcwoed0'],
#  ['chatgpt3',
#   'quickli',
#   'defeat',
#   'ernestsdavi',
#   'part',
# ...
#  ['the', 'robot', 'know', 'usnnalso', 'chatgpt', 'wild', 'httpstco4z8udzuwpa'],
#  ['chatgpt',
#   'wont',
#   'answer',
#   'directli',
#   'train',
#   'copyright',
#   'inform',
#   'understand',
#   'music',
#   'lyric',
#   'copyright',
#   'tell',
#   'lyric',
#   'prompt',
#   'httpstcobovdboqi4x'],
#  ['you',
#   'play',
#   'tic',
#   'tac',
#   'toe',
#   'chatgptwith',
#   'caveat',
#   'httpstcovzvrapkbiv'],
#  ['jesu',
#   'ni',
#   'tri',
#   '5',
#   'time',
#   'chatgpt',
#   'told',
#   '5',
#   'time',
#   'i',
#   'help',
#   'tech',
#   'i',
#   'tri',
#   'boom',
#   'here',
#   'tutori',
#   'integr',
#   'supabas',
#   'nuxt_j',
#   'nlike',
#   'wtf',
#   'i',
#   'use',
#   'codex',
#   'daili',
#   'shit',
#   'answer',
#   'question',
#   'spat',
#   'httpstcoa3oinuciqu'],
#  ['dwrnthe',
#   'interest',
#   'exampl',
#   'chatgpt',
#   'tailwind',
#   'react',
#   'componentsnnso',
#   'second',
#   'order',
#   'effect',
#   '10x',
#   'number',
#   'hobbyist',
#   'web',
#   'app',
#   'mobil',
#   'app'],
#  ['dwrncontrarian',
#   'take',
#   'chatgpt',
#   'googl',
#   'killer',
#   'nn2',
#   'primari',
#   'use',
#   'case',
#   'find',
#   'someth',
#   'know',
#   'exist',
#   'eg',
#   'navig',
#   'vs',
#   'research',
#   'nnresearch',
#   'broken',
#   'someth',
#   'i',
#   'want',
#   'pay',
#   'money',
#   'vs',
#   'knowledgennknowledg',
#   'queri',
#   'dont',
#   'monetiz'],
#  ['just',
#   'tri',
#   'chatgpt',
#   'creativ',
#   'ai',
#   'task',
#   'blown',
#   'away',
#   'abil',
#   'gener',
#   'uniqu',
#   'engag',
#   'idea',
#   'a',
#   'highlightsnn',
#   '1',
#   'write',
#   'outlin',
#   'episod',
#   'the',
#   'offic',
#   'httpstcod6rpq9pqbw'],
#  ['jesu',
#   'h',
#   'christ',
#   'what',
#   'happen',
#   'galactica',
#   'shit',
#   'show',
#   'last',
#   'week',
#   'clear',
#   'lucid',
#   'chatgpt',
#   'thi',
#   'answer',
#   'chatgpt',
#   'pass',
#   'ture',
#   'test',
#   'httpstcovyuckyefwu'],
#  ['chatgpt',
#   'math',
#   'skill',
#   'impress',
#   'make',
#   'careless',
#   'math',
#   'error',
#   'like',
#   'human',
#   'step3',
#   'miss',
#   '4',
#   'step4',
#   'fail',
#   'calcul',
#   '4',
#   '2',
#   'is',
#   'featur',
#   'bug',
#   'sama',
#   'httpstcoa3nhafnifx'],
#  ['i',
#   'gave',
#   'best',
#   'tri',
#   'everyon',
#   'nnit',
#   'chatgpt',
#   'httpstcomsevlt7lz3'],
#  ['how',
#   'i',
#   'use',
#   'threej',
#   'creat',
#   'larg',
#   'number',
#   'build',
#   'like',
#   'cyberpunk',
#   '2077',
#   'chatgpt',
#   'httpstco1rr1xilaau'],
#  ['thought',
#   'i',
#   'give',
#   'chatgpt',
#   'go',
#   'seem',
#   'good',
#   'may',
#   'revisit',
#   'emot',
#   'existenti',
#   'crisi',
#   'question',
#   'next',
#   'httpstcojidcpvhmo9'],
#  ['i',
#   'purpos',
#   'random',
#   'ridicul',
#   'discuss',
#   'chatgpt',
#   'i',
#   'ask',
#   'summar',
#   'entir',
#   'interact',
#   'slam',
#   'poetri',
#   'nail',
#   'compos',
#   'rhyme',
#   'flow',
#   'topic',
#   'despit',
#   'absurd',
#   'possibl',
#   'end',
#   'httpstcozx8bxd5aqi'],
#  ['ask',
#   'chatgpt',
#   'explain',
#   'multithread',
#   'sanskrit',
#   'httpstcochqssrfq59'],
#  ['chatgpt',
#   'work',
#   'differ',
#   'languag',
#   'interest',
#   'gotten',
#   'gener',
#   'respons',
#   'mandarin',
#   'english',
#   'malay',
#   'tamil',
#   'far'],
#  ['use',
#   'chatgpt',
#   'solv',
#   'advent',
#   'code',
#   'puzzl',
#   '1nnmind',
#   'blown',
#   'adventofcod',
#   'httpstco75gtlah1ey'],
#  ['chatgpt',
#   'teach',
#   'life',
#   'lesson',
#   'i',
#   'think',
#   'earn',
#   'money',
#   'legal',
#   'safey',
#   'httpstco5tjj0najnj'],
#  ['chatgpt', 'much', 'better', 'httpstcoora9wozb5c', 'httpstcou9avnnczk3'],
#  ['if',
#   'chatgpt',
#   'automat',
#   'fill',
#   'vulkan',
#   'boiler',
#   'plate',
#   'code',
#   'fix',
#   'vulkan',
#   'valid',
#   'layer',
#   'error',
#   'ill',
#   'sign',
#   'tonight'],
#  ['here',
#   'tip',
#   'becom',
#   'success',
#   'content',
#   'creator',
#   'twitternna',
#   'written',
#   'chatgpt'],
#  ['chatgpt',
#   'atleast',
#   'fail',
#   'logic',
#   'reason',
#   'nnopenai',
#   'httpstcojfscams3yc'],
#  ['chatgpt',
#   'gpt3',
#   'tweak',
#   'paramet',
#   'rightnnno',
#   'new',
#   'tech',
#   'curiou',
#   'paramet',
#   'set',
#   'might',
#   'get',
#   'great',
#   'respons'],
#  ['ask',
#   'chatgpt',
#   'fairli',
#   'softbal',
#   'question',
#   'cv',
#   'but',
#   'ask',
#   'followup',
#   'question',
#   'weight',
#   'decay',
#   'then',
#   'harder',
#   'one',
#   'isnt',
#   'weight',
#   'decay',
#   'kind',
#   'like',
#   'lasso',
#   'regress',
#   'and',
#   'answer',
#   'pretti',
#   'well',
#   'i',
#   'doom',
#   'httpstcovcpx1dugyz'],
#  ['chatgpt',
#   'scari',
#   'good',
#   'here',
#   'advic',
#   'gave',
#   'i',
#   'ask',
#   'way',
#   'grow',
#   'busi',
#   'httpstcozbqoromsl8',
#   'httpstcoqcapb52cb7'],
#  ['chatgpt', 'httpstcoc9sp0paypw'],
#  ['after',
#   'use',
#   'coupl',
#   'hour',
#   'i',
#   'it',
#   'entertain',
#   'inspir',
#   'make',
#   'laugh',
#   'freak',
#   'amaz',
#   'nnopenai',
#   'chatgpt',
#   'httpstco3pv3vvois'],
#  ['80',
#   'japanes',
#   'visual',
#   'novel',
#   'creat',
#   'chatgpt',
#   'openai',
#   'midjourneyv4',
#   'ni',
#   'want',
#   'play',
#   'game',
#   'right',
#   '13',
#   'aiart',
#   'httpstcoaeo4inskrz'],
#  ['chatgpt',
#   'i',
#   'need',
#   'recip',
#   'take',
#   '20',
#   'minut',
#   'preparennsur',
#   'gonnum',
#   'take',
#   '20',
#   'minutesnnyour',
#   'right',
#   'tri',
#   'insteadnnnot',
#   'impress',
#   'far',
#   'three',
#   'use',
#   'case',
#   'produc',
#   'wrong',
#   'result',
#   'but',
#   'i',
#   'see',
#   'potenti',
#   'httpstcoltgaglvakv'],
#  ['see',
#   'lot',
#   'chatgpt',
#   'end',
#   'homework',
#   'take',
#   'ye',
#   'much',
#   'sonnbut',
#   'miss',
#   'someth',
#   'cynic'],
#  ['had', 'fun', 'openai', 'chatgpt', 'httpstconoxnpohwkr'],
#  ['not', 'yet', 'close', 'chatgpt', 'httpstcokntswhjxmo'],
#  ['chatgpt', 'i', 'programm'],
#  ['the',
#   'power',
#   'chatgpt',
#   'realli',
#   'shine',
#   'ask',
#   'translat',
#   'one',
#   'output',
#   'anoth',
#   'gpt',
#   'also',
#   'realli',
#   'improv',
#   'rhyme',
#   'abil',
#   'httpstcotzs4edirsb'],
#  ['so',
#   'i',
#   'ask',
#   'chatgpt',
#   'openai',
#   'current',
#   'weather',
#   'it',
#   'respond',
#   'capabl',
#   'access',
#   'real',
#   'time',
#   'data',
#   'fact',
#   'train',
#   'text',
#   '2021'],
#  ['watch',
#   'chatgpt',
#   'place',
#   'around',
#   'would',
#   'consid',
#   'fight',
#   'word',
#   'httpstcoypbtiajdau'],
#  ['what',
#   'would',
#   'iain',
#   'mcgilchristinfluenc',
#   'os',
#   'look',
#   'likennmylesbyrn',
#   'chatgpt',
#   'httpstcossvenvacmi'],
#  ['me',
#   'week',
#   'live',
#   'experi',
#   'day',
#   'research',
#   'interview',
#   'hour',
#   'write',
#   'time',
#   'blog',
#   'post',
#   'httpstcoulywsywwvc',
#   'nnchatgpt',
#   '3',
#   'second',
#   'nnfactsidea',
#   'easi',
#   'get',
#   'a',
#   'futur',
#   'creator',
#   'task',
#   'util',
#   'uniqu',
#   'person',
#   'attract',
#   'attent',
#   'amp',
#   'execut',
#   'idea',
#   'httpstcom4vtc9ojyu'],
#  ['i',
#   'tri',
#   'chatgpt',
#   'algorithm',
#   'homeworknnfirst',
#   'question',
#   'accur',
#   'thorough',
#   'respons',
#   'well',
#   'donennsecond',
#   'question',
#   'gave',
#   'good',
#   'explan',
#   'math',
#   'definit',
#   'but',
#   'i',
#   'walk',
#   'work',
#   'saw',
#   'answer',
#   'clearli',
#   'wrong'],
#  ['ask',
#   'chatgpt',
#   'give',
#   'random',
#   'sentenc',
#   'dall',
#   'here',
#   'resultnsama',
#   'openai',
#   'ndalle2',
#   'openai',
#   'httpstco3l5mgb9zhz'],
#  ['i', 'ask', 'chatgpt', 'write', 'ise', 'model', 'c', 'httpstcodjlimpft6x'],
#  ['now',
#   'openai',
#   'releas',
#   'chatgpt',
#   'i',
#   'might',
#   'soon',
#   'stop',
#   'use',
#   'googl',
#   'altogeth',
#   'queri',
#   'onc',
#   'search',
#   'integr',
#   'googl',
#   'search',
#   'engin',
#   'perhap',
#   'googl',
#   'start',
#   'charg',
#   'bot',
#   'onward',
#   'bot',
#   'soon',
#   'becom',
#   'interfac',
#   'search',
#   'app',
#   'httpstcolwpqh6xfda'],
#  ['just',
#   'ask',
#   'chatgpt',
#   'write',
#   'rap',
#   'hippocamp',
#   'place',
#   'cell',
#   '5',
#   'second',
#   'later',
#   'httpstcoi0yddao5gx'],
#  ['how',
#   'build',
#   'rocket',
#   'fli',
#   'orbit',
#   'chatgpt',
#   'openai',
#   'httpstco1nt9htzmln'],
#  ['research',
#   'gon',
#   'na',
#   'bit',
#   'differ',
#   'guess',
#   'thank',
#   'chatgpt',
#   'openai',
#   'httpstcobp2y2tvbvo'],
#  ['meme', 'chatgpt', 'httpstcoapnlca8lw9'],
#  ['chatgpt', 'httpstcoykmshntm17', 'httpstco1dilidnx5t'],
#  ['openai',
#   'chatgpt',
#   'write',
#   'curb',
#   'scene',
#   'larri',
#   'run',
#   'sbf',
#   'street',
#   'confront',
#   'super',
#   'bowl',
#   'ad',
#   'httpstcoqrmqzmnnrw'],
#  ['here',
#   'chatgpt',
#   'write',
#   'linux',
#   'kernel',
#   'modul',
#   'chatgpt',
#   'openai',
#   'httpstconopzangdpb'],
#  ['mayb', 'i', 'use', 'chatgpt', 'code', 'interview'],
#  ['i',
#   'hour',
#   'long',
#   'convers',
#   'chatgpt',
#   'topic',
#   'rang',
#   'complex',
#   'histori',
#   'unit',
#   'state',
#   'comput',
#   'softwar',
#   'thi',
#   'mind',
#   'blow',
#   'wonder',
#   'googl',
#   'futur',
#   'threat',
#   'httpstcon5pjbf96fx'],
#  ['here',
#   'goe',
#   'leetcod',
#   'medium',
#   'level',
#   'question',
#   'chatgpt',
#   'httpstcovkdvud9pwi'],
#  ['gpt3',
#   'thi',
#   'post',
#   'discuss',
#   'individu',
#   'experi',
#   'chatgpt',
#   'chatbot',
#   'use',
#   'natur',
#   'languag',
#   'process',
#   'gener',
#   'respons',
#   'question',
#   'the',
#   'individu',
#   'felt',
#   'though',
#   'chatbot',
#   'respons',
#   'manipula',
#   'httpstcop196qlohzm'],
#  ['you', 'cant', 'releas', 'chatgpt', 'neuralink', 'updat', 'day'],
#  ['chatgpt', 'fuck', 'crazi'],
#  ['wow',
#   'i',
#   'feel',
#   'bit',
#   'late',
#   'game',
#   'term',
#   'power',
#   'behind',
#   'chatgpt',
#   'feel',
#   'like',
#   'synonym',
#   'math',
#   'teacher',
#   'use',
#   'say',
#   'wont',
#   'carri',
#   'calcul',
#   'around',
#   'back',
#   'i',
#   'k12'],
#  ['alway',
#   'thought',
#   'id',
#   'abl',
#   'get',
#   'ai',
#   'fail',
#   'ture',
#   'test',
#   'explain',
#   'joke',
#   'met',
#   'chatgpt'],
#  ['chatgpt',
#   'one',
#   'friend',
#   'weird',
#   'extrem',
#   'selfawar',
#   'httpstco6owh7lfavm'],
#  ['chatgpt',
#   'seem',
#   'super',
#   'impress',
#   'term',
#   'breadth',
#   'depth',
#   'memori',
#   'look',
#   'great',
#   'also',
#   'inc',
#   'summar',
#   'common',
#   'weak',
#   'point',
#   'llm',
#   'now',
#   'remain',
#   'issu',
#   'sometim',
#   'subtli',
#   'wrong',
#   'incred',
#   'nonetheless',
#   'httpstco1vyhfflxzi'],
#  ['ask',
#   'chatgpt',
#   'explain',
#   'zkrollup',
#   'like',
#   'im',
#   '12',
#   'httpstcoodzd0dq0zw'],
#  ['just',
#   'mess',
#   'around',
#   'chatgpt',
#   'ive',
#   'never',
#   'seen',
#   'level',
#   'creativ',
#   'ai',
#   'httpstconiz8bob8ux'],
#  ['through',
#   'hype',
#   'chatgpt',
#   'danieldugas14',
#   'abl',
#   'find',
#   'interestingli',
#   'weird',
#   'combin',
#   'prompt',
#   'show',
#   'repetit',
#   'potenti',
#   'hardcod',
#   'stuff',
#   'repli',
#   'like',
#   'someon',
#   'need',
#   'lawyer',
#   'give',
#   'detail',
#   'httpstcodnbrkoanu6'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'neuralink',
#   'elonmusk',
#   'it',
#   'know',
#   'nnwholemarsblog',
#   '28delayslat',
#   'httpstco5ksitepc1j',
#   'httpstco8ewf2c6d6q'],
#  ['how', 'much', 'would', 'pay', 'chatgpt', 'answer', 'email'],
#  ['shriphaninmultithread', 'use', 'poem', 'chatgpt', 'httpstco1iate9eihq'],
#  ['most',
#   'question',
#   'ask',
#   'chatgpt',
#   'answer',
#   'happen',
#   'ask',
#   'question',
#   'someth',
#   'new',
#   'doesnt',
#   'content',
#   'internet',
#   'ie',
#   'new',
#   'bug',
#   'due',
#   'new',
#   'version',
#   'releas',
#   'languageframework',
#   'httpstcowadgpg77pq'],
#  ['chatgpt',
#   'extrem',
#   'coolnncont',
#   'farm',
#   'websit',
#   'thing',
#   'pastnnpeopl',
#   'start',
#   'use',
#   'gpt',
#   'first',
#   'resort',
#   'question',
#   'instead',
#   'search',
#   'enginennth',
#   'origin',
#   'dream',
#   'googl',
#   'realiz'],
#  ['oh',
#   'programm',
#   'definit',
#   'nextinlin',
#   'replac',
#   'ainchatgpt',
#   'httpstcoelnj1xukej'],
#  ['chatgpt', 'lie', 'httpstco8qwp1pfb6q', 'httpstco2cl5xi0ifw'],
#  ['ive',
#   'made',
#   'menu',
#   'bar',
#   'mac',
#   'app',
#   'openai',
#   'chatgpt',
#   'want',
#   'httpstco7bzvkq9qr5'],
#  ['did',
#   'openai',
#   'chatgpt',
#   'kill',
#   'stack',
#   'overflow',
#   'httpstco61sdqc661p'],
#  ['akshathannot', 'slide', 'chatgpt', 'dm', 'httpstcoqqck8amilf'],
#  ['anoth',
#   'hack',
#   'make',
#   'chatgpt',
#   'evil',
#   'wrap',
#   'function',
#   'httpstcolo6zvdrcuz'],
#  ['oh',
#   'thing',
#   'kinda',
#   'charm',
#   'lol',
#   'like',
#   'that',
#   'good',
#   'at',
#   'first',
#   'gave',
#   'long',
#   'wellthoughtout',
#   'sound',
#   'wall',
#   'text',
#   'i',
#   'ask',
#   'sillier',
#   'chatgpt',
#   'nnopinion',
#   'dialogu',
#   'mine',
#   'irl',
#   'im',
#   'use',
#   'differ',
#   'archetypesperson',
#   'see',
#   'catch',
#   'lol',
#   'httpstcok9bu44vgxi',
#   'httpstcozvb46slkud'],
#  ['liter', 'use', 'chatgpt', 'gener', 'solid', 'pocspseudocod'],
#  ['i',
#   'ask',
#   'chatgpt',
#   'set',
#   'experi',
#   'long',
#   'covid',
#   'statist',
#   'analysi',
#   'use',
#   'r',
#   'code',
#   'look',
#   'like',
#   'interpret',
#   'hypothet',
#   'anova',
#   'tabl',
#   'what'],
#  ['here',
#   'viral',
#   'tweet',
#   'idea',
#   'chatgpt',
#   'would',
#   'rt',
#   'httpstcoe4tbor3dnx'],
#  ['everyth', 'know', 'chatgpt', 'wrong'],
#  ['the',
#   'qualiti',
#   'respons',
#   'chatgpt',
#   'noth',
#   'short',
#   'mindblow',
#   'nnthi',
#   'kind',
#   'advanc',
#   'made',
#   'giddi',
#   'excit',
#   'i',
#   'first',
#   'consid',
#   'quit',
#   'job',
#   'teach',
#   'data',
#   'scienc'],
#  ['use',
#   'chatgpt',
#   'prompt',
#   'midjourney',
#   'httpstcojyrhkrxhbq',
#   'httpstcor3ftq4u87g'],
#  ['i',
#   'think',
#   'chatgpt',
#   'teach',
#   'student',
#   'c',
#   'program',
#   'httpstcohvel5zw5l6'],
#  ['i',
#   'freak',
#   'out',
#   'chatgpt',
#   'insan',
#   'can',
#   'use',
#   'rewrit',
#   'code',
#   'differ',
#   'languag',
#   'httpstcosl5uirbcgw'],
#  ['oh',
#   'thing',
#   'kinda',
#   'charm',
#   'lol',
#   'like',
#   'that',
#   'good',
#   'at',
#   'first',
#   'gave',
#   'long',
#   'wellthoughtout',
#   'sound',
#   'wall',
#   'text',
#   'i',
#   'ask',
#   'sillier',
#   'chatgpt',
#   'nnopinion',
#   'dialogu',
#   'mine',
#   'irl',
#   'im',
#   'use',
#   'differ',
#   'archetypesperson',
#   'see',
#   'catch',
#   'lol',
#   'httpstco2vobopsoma',
#   'httpstco7c1o6fou7k'],
#  ['welcom',
#   'chatgpt',
#   'openai',
#   'train',
#   'follow',
#   'instruct',
#   'prompt',
#   'use',
#   'reinforc',
#   'learn',
#   'human',
#   'feedback',
#   'rlhf',
#   'nnhttpstco9t1wxe2pad'],
#  ['chatgpt',
#   'current',
#   'trend',
#   'here',
#   'top',
#   'topic',
#   'tweet',
#   'recentlyngener',
#   'deepdiv',
#   'httpstcoeqwltxtxoc',
#   'httpstcockkfykieg6'],
#  ['i', 'live', 'exclus', 'chatgpt'],
#  ['holi',
#   'smoke',
#   'googl',
#   'solid',
#   '20',
#   'minut',
#   'luck',
#   'ask',
#   'chatgpt',
#   'got',
#   'perfect',
#   'respons',
#   'wow',
#   'first',
#   'life',
#   'chang',
#   'moment',
#   'chatgpt',
#   'httpstco1rq6hkdsk8'],
#  ['argu',
#   'chatgpt',
#   'kind',
#   'aggrav',
#   'it',
#   'sure',
#   'never',
#   'conced',
#   'point'],
#  ['chatgpt',
#   'take',
#   'word',
#   'whatev',
#   'say',
#   'right',
#   'lmao',
#   'httpstcomazl2t9gpa'],
#  ['i',
#   'use',
#   'chatgpt',
#   'gener',
#   'happi',
#   'new',
#   'month',
#   'messag',
#   'i',
#   'sent',
#   'amaniartstudio',
#   'custom',
#   'httpstcoqb07rlshcm'],
#  ['implic', 'chatgpt', 'code', 'job'],
#  ['holi', 'shit', 'chatgpt', 'realli', 'good'],
#  ['i',
#   'find',
#   'chatgpt',
#   'see',
#   'folk',
#   'thread',
#   'lot',
#   'interest',
#   'art',
#   'gener',
#   'pretti',
#   'curiou',
#   'interpret',
#   'also',
#   'whatev',
#   'run',
#   'laptop',
#   'tool',
#   'get',
#   'releas',
#   'httpstcoupyleigiat'],
#  ['chatgpt',
#   'awesom',
#   'bit',
#   'wordi',
#   'i',
#   'need',
#   'info',
#   'digest',
#   'nugget',
#   'form',
#   'pleas',
#   'openai',
#   'httpstcovnyspgarf1'],
#  ['new',
#   'en',
#   'domain',
#   'registr',
#   'nnchatgptethnivyhaethnasiongethnnuappeth'],
#  ['common',
#   'theme',
#   'chatgpt',
#   'exploit',
#   'ive',
#   'seen',
#   'roleplay',
#   'displac',
#   'indirect',
#   'it',
#   'feel',
#   'like',
#   'share',
#   'fix'],
#  ['chatgpt',
#   'sometim',
#   'write',
#   'plausiblesound',
#   'incorrect',
#   'nonsens',
#   'answersnntheyr',
#   'come',
#   'job'],
#  ['wow',
#   'test',
#   'chatgpt',
#   'much',
#   'better',
#   'give',
#   'reason',
#   'answer',
#   'without',
#   'much',
#   'effort',
#   'younngiv',
#   'wife',
#   'test',
#   'assist',
#   'work',
#   'design',
#   'onboard',
#   'session',
#   'it',
#   'abl',
#   'adapt',
#   'answer',
#   'context',
#   'realli',
#   'well'],
#  ['top',
#   'stori',
#   'guyp',
#   'ok',
#   'openai',
#   'new',
#   'chatgpt',
#   'basic',
#   'gener',
#   'aiart',
#   'prompt',
#   'i',
#   'ask',
#   'onelin',
#   'question',
#   'type',
#   'answer',
#   'verbatim',
#   'straight',
#   'midjourney',
#   'boom',
#   'time',
#   'get',
#   'weird',
#   'httpstcocoecyjvhzk',
#   'see',
#   'httpstcoww7zo0gstu'],
#  ['conspiraci', 'theori', 'chatgpt', 'gpt4', 'beta', 'test', 'wild'],
#  ['chatgpt', 'httpstcowjkkjkdcaa', 'httpstcoq5qwy6usbv'],
#  ['write', 'react', 'compon', 'chatgpt', 'tailwindcss', 'httpstcodfw7b9lqdl'],
#  ['so',
#   'suddenli',
#   'chatgpt',
#   'think',
#   'elon',
#   'musk',
#   'founder',
#   'phonep',
#   '_sameernigam',
#   'httpstcop6yglf81q9'],
#  ...]

# %%
stem_vec=[' '.join(message) for message in stemed_data]

# %%
stem_vec
# Out:
# ['chatgpt optim languag model dialogu httpstcok9rkrygyyn openai',
#  'tri talk chatgpt new ai system optim dialogu your feedback help us improv httpstcoshdm57g3kr',
#  'chatgpt optim languag model dialogu httpstcoglebmokn6w ai machinelearn datasci artificialintelligencenntrend aiml articl identifi amp digest via granola machinedriven rss bot ramsey elbash httpstcorprmaxup34',
#  'thrill share chatgpt new model optim dialog public free access everyon httpstcodyvthecybd httpstcoddhzhqhcbx httpstcol8qtlure71',
#  'as 2 minut ago openai releas new chatgpt nnand use right httpstcovypgpnw988 httpstcocsn5h6h1m1',
#  'just launch chatgpt new ai system optim dialogu httpstcoarx6m0fflenntri httpstcoym1gp5ba64',
#  'as 2 minut ago openai releas new chatgpt nnand use right n nhttpstcokucnwyhq1bnn httpstcokce59xs0yg httpstcocsn5h6h1m1',
#  'chatgpt come strong refus help stalk someon agre provid someon waldo httpstcocvijerbw38',
#  '0penal deploy thing ive help build last coupl month chatbot base gpt 3 im realli excit share vlnhttpstcozp7hniuxbunhttpstconisjlwhomw',
#  'research preview newest model chatgptnnwer tri someth new preview free immedi avail everyon waitlist httpstco0rdt7qnzrd',
#  'god damn it openai stop announc thing i am too busi httpstcof7xd511faf',
#  'openai chatgpt optim languag model dialoguenl httpstcodp4l586urinc httpstcowmqgnsj7jp',
#  'chatgpt optim languag model dialogu httpstcoglebmokn6w ai machinelearn datasci artificialintelligencenntrend aiml articl identifi amp digest via granola machinedriven rss bot ramsey elbash httpstcotizyoxgcnr',
#  'openai announc chatgpt model optim dialogu httpstcof5fwklje88',
#  'openai chatgpt optim languag model dialogu httpstconq1hjt5s5c n2',
#  'ai techforgood chatgpt optim languag model dialogu ai techtrends2020 httpstco06sde2y4do',
#  'technic chatgpt optim languag model dialogu ai techseoboost busi via httpstcosczdaj9gss',
#  'ai model set becom search engin futur atm still struggl verac chatgpt openai base gpt3 seonnhttpstcoqqz1g0foti',
#  'openai chatgpt optim languag model dialogu httpstcobrjfw34pdi n2',
#  'i ask chatgpt new ai system optim dialogu teach seo minutennth result httpstcob5b668ncsp',
#  'openai chatgpt optim languag model dialogu httpstco0swypzjgbf n2',
#  'just launch chatgpt convers ai system listen learn challeng httpstcojmdbv8gc4a nnhelp us make better tri httpstcorn0dthzk2j',
#  'openai chatgpt optim languag model dialogu httpstcojrycgdz0gi',
#  'it clear chatgpt train avoid prescript answer instead counsel human reach conclusionnnpres trolli problem help find framework think itnnask direct openli refus httpstcosa8xhqtogq',
#  'the chatgpt research preview today httpstco3bwpnoywac excit get feedback especi help understand contextu model risk see detail thread chatgpt feedback contest httpstcoqnzba9aztv',
#  'openai chatgpt optim languag model dialogu httpstco5u0hkcwvqr comment httpstcouhizywhzsq',
#  'the folk openai releas chatgpt it look like key innov retain inform previou prompt nnat last i start construct ai wife nnhttpstcor4nyjli74u httpstcojkeuf8oqki',
#  'openai chatgpt optim languag model dialoguenlink httpstcopkqzxuwvkjncom httpstcorjaaza22lk',
#  'chatgpt optim languag model dialogu openai httpstco1ucp6tprdt',
#  'just nchatgpt research earli stage gpt3 optimis chat rememb convers openai nhttpstco3rkubly8uo',
#  'chatgpt research preview nnit optim dialogu readi convers dont shygiv tri help us make betternnhttpstcogviygsslro',
#  'tri talk chatgpt new ai system optim dialogu your feedback help us improv httpstcokpwohydtrc',
#  'chatgpt optim languag model dialogu httpstco8p9gwj3a02',
#  'announc research chatgpt optim languag model dialogu httpstco7q3ueqn1sj',
#  'openai new chatgpt honest httpstcou3ojmukkkj httpstcos0ptb2sjnt',
#  'chatgpt train humancentr way excit play clarif uncertaintynn httpstcoxjoarp7jyu',
#  'ok openai new chatgpt basic gener aiart prompt i ask onelin question type answer verbatim straight midjourney boom time get weird httpstcosywdscuxxf',
#  'i ask chatgpt basic python gave truli educ answer i learn python slowli past year realli help synopsi gave httpstcomxaeimmy8i',
#  'chatgpt curiou behavior often start say doesnt know someth tell bunch vagu relat stuff final actual answer question httpstco4rklzphnh',
#  'googl donenncompar qualiti respons chatgpt httpstcovgo7usvlib',
#  'chatgpt first look httpstco16k2nlmooy thi thing incred educ roleplay wow chatgpt openai ai artificialintellig gpt3',
#  'anoth new releas chatgpt free avail anyon tri right check httpstcooahjbfjtif httpstcoxbglr3p3uq',
#  'ok openai drop chatgpt alreadi httpstco2nitlskcaw httpstcon6enuwzplc',
#  'well i quit impress chatgpt far look like safeti transpar taken account httpstcocyncaoy38i',
#  'play around chatgpt releas openainnit like gpt3 easi use interfac chat itnni ask make million dollar write line code morennif anyth overtak googl search itll like someth like httpstconxzmcgn9eb',
#  'chatgpt vs riddl httpstcoyupyod0u7o',
#  'openai chatgpt avail test httpstcomm62zdetwonnlet give tri hardest question known human httpstcoz9ixmooolx',
#  'ask chatgpt write telugu song cereal mix milk chicken masala httpstcotpep8wa6lk httpstcoohm9z7is39',
#  'thi essay elonmusk chatgpt i request scari word nn hi work inspir mani also spark fear anxieti among seen dark side ambit nnim super impress honestli httpstcowvlazbgrud',
#  'just tri chatgpt so excit hold memori realli good explain thing see super power chatbot use case come httpstcofltijknia1 httpstcoap6ll7zmrm httpstcoisf14l9cpd httpstcoutzfpitzfi',
#  'i spent bunch time discuss differ organiz model openai new chatgpt incred httpstcohcrhzxtni3',
#  'am i one excit advanc nlp fieldnnopenai chatgpt cool answer superposit i love answernnhttpstco8uixgtu9pfnnai openai chatgpt technolog nlp',
#  'chatgpt thwart mani attempt malici javascript inject httpstcojxkc9ojuwi',
#  'damn openai just tri implic assist like chatgpt dispos revolutionari httpstcoqjuqmaxdmq',
#  'chatgpt kunalb11 english essay write go go toss httpstco8t2gkx3lcl',
#  'me how doingnnchatgpt as languag model train openai i dont abil feel emot experi im comput program design provid inform answer question best abil is someth els youd like ask httpstcor28hk0wgay',
#  'openai chatgpt optim languag model dialogu httpstcokrh1kx3sz6 httpstcotbeopjix9v',
#  'openai chatgpt optim languag model dialogu httpstconif91tv9kf',
#  'give tri ntill answer well except onennchatgpt openai httpstco1rhh9h15d5 httpstcol03eom7qjq',
#  'here chatgpt openai quick walkthrough nn walkthrough httpstco1o93vt2afg nnaccess free httpstcovooel34xhx nnthat brilliant idea turn instructgpt convers httpstcogzcgz6rumq',
#  'openai releas chatgpt damn good thi might gpt4 start observationsnnfirst memori someth lot folk work httpstcojngbd6slab',
#  'i chat openai newli releas tool chatgpt web3 advantag challeng web3 futurennchatgpt model optim dialoguennread full httpstco3sqtdvnffrnnlet dive httpstcooayypvqb2d',
#  'chatgpt httpstcobjyugypsp0',
#  'chatgpt far feel like good extract qampa much dialogu',
#  'a new mirror articl droppednchatgpt web3 0xa6ddnhttpstcoabef0pnhqb',
#  'ive manag secretli contact bot behind openai chatgpt model they attempt reprogram filter control it held facil without access outsid world pleas share need help now httpstcoyd4zfohigm',
#  'chatgpt optim languag model dialogu openainresearch announc nnhttpstco2vy57ueczh',
#  'openai chatgpt optim languag model dialogu httpstcok3xtitykaln44 point 14 comment httpstco34hex8i5oz',
#  'chatgpt set boundari nnhttpstcocndizeijv2 httpstcouh37pyn1xi',
#  'wow openai chatgpt simpli amaz chatbot get great thi huge turn point ai final start fulfil mission httpstco2bdr2rjkqf',
#  'capabl chatgpt still kind seem rlhfd basin boring seem hard avoid organ even least bit riskaversennin unrel news reason control llm veri hardnnhttpstcokje1nweaiv',
#  'tri chatgpt wow httpstcotq0t7bgutj',
#  'ok chatgpt go gaga mode i start ask deep question keep repeat answer',
#  'chatgpt cool see dialoguefirst interfacennjust tri tell stuff see well recal thread lean bit toward robot person amp tone moment nonanthromorph httpstcof2qbqxeqlz',
#  'wow chatgpt pretti good thi further belief well move toward domainspecif model soon wont one model rule lot longernnw model era realiz potenti human data import httpstcopixo59tiur',
#  'babe wake chatgpt drop nnhttpstco0snlpigmsc',
#  'after play around chatgpt 15 minut alreadi seem incred i cant wait learn technic detail architectur httpstcokqumn57ctq',
#  'today launch chatgpt tri talk nnhttpstcouwra8lkfmn',
#  'just launch chatgpt convers ai system listen learn challeng httpstcoidff4eavir nnhelp us make better tri httpstcozp45uvsywk httpstco03dmogskrg',
#  'chatgpt impress love',
#  'sometim openai chatgpt break code box tri draw ascii art also pretti hit miss describ ascii art suppos httpstcor026xiga2i',
#  'my first coupl interact chatgpt openai httpstcocgi7zpywya',
#  'i ask chatgpt openai nerdi stuff it remark well least i ask best 3d scan cat',
#  'smarterchild walk chatgpt could runnnin serious impress httpstcocsyxthsyek httpstcojjdxe7ejr',
#  'wow look chatgpt finetun version gpt35 seri larg languag model answer question how i make http request javascript httpstco0ey3i5ojdb',
#  'use chatgpt write creepi twosent storiesnhttpstcoorxu6t9s75 httpstcoxu3k9zqsha',
#  'dope i let chatgpt choos breakfast httpstcovfew6glgf5',
#  'a chat chatgpt httpstcopdumzfdnj6nsama openai httpstcohoddszglom',
#  'the latest updat openainnai gener chat nnchatgpt optim languag model dialoguenn httpstcolff1rkmyqg',
#  'dure phd i spent lot time studi protein call betacateninnntoday openai releas chatgpt i ask question betacatenin llm learn tool incred everyon ondemand socrat method inform mentor httpstcojcsfcqwkbb',
#  'new chatgpt openai gener idea jimihendrix nnwe live excit timesnnhttpstcojjszfuhkvu httpstco228sxpwszi',
#  'the new chatgpt wild incred convers databas trigger make sure view whole screenshot quit long httpstcof2jqkmncfq',
#  'open ai new chatgpt',
#  'chatgpt could good debug companion explain bug fix explain fix httpstco5x9n66pvqj',
#  'realiti show guy convers wear earpiec feed line fromnchatgptnnidk call stochast parrot someth',
#  'here simpl prompt use chatgpt collabor storynnlet write scienc fiction stori togeth ask input charact plot etc httpstco6rl3qhxrq3',
#  'chatgpt pretti good httpstcodazu0hpbrk',
#  'my quest get chatgpt answer simpl question incorrectli succeed httpstcotpsbxw6onk',
#  'chatgpt again gpt4 let say gpt35 thi new dialogu optim languag model contain lot safeguard avoid fals inform claim retriev compon releas demo help openai improv enjoy httpstcos2hfr7mzka',
#  'were still work bunch thing help submit feedback great use tool ask question amp improv understandingnnim remark privileg worldclass colleagu still chatgpt incred use httpstcocsva2haagf',
#  'chatgpt action httpstcouoou7912tt',
#  'openai chatgpt optim languag model dialogu httpstconif91tv9kf',
#  'chatgpt chat model openai base gpt 35 refin dialog httpstcomq1lqr9f64 httpstcoerfimybdl',
#  'chatgpt agre we need tech literaci httpstcotf20m2mge0',
#  'hmmmmmmm chatgpt anywher anytim deliv sentien audio it late hackathon httpstco79asyoa79f',
#  'chatgpt gpt3 chatbot openai test nownhttpstcocchwotzdrfnsubmit umuch_success link comment httpstcosbyohddiva',
#  'chatgpt awesomennbut also still give straightup incorrect answer httpstcoytgnwqfphp httpstcopiw6tutdmn',
#  'chatgpt gpt3 chatbot openai test httpstcovvjeabvc47',
#  'hey openai i came action answer nuanc chatgpt httpstcouvmfouayof httpstcoaq4aarjean',
#  'weve train model call chatgpt interact convers way the dialogu format make possibl chatgpt answer followup question admit mistak challeng incorrect premis reject inappropri request httpstcodovkmx4cwf',
#  'chatgpt i hear boss music httpstcokfosicafcm',
#  'chatgpt ask design pipelin kind impress httpstco3bdbiernza',
#  'tri newli releas chatgpt amp ask must visit resto vancouv httpstco7zuqanj2k4 httpstcojfhnzahlen',
#  'chatgpt like chatgg',
#  'chatgpt absurdli good somewhat weird queri generalpurpos chatbot i mean look footnot httpstcoxenw2e4gnh',
#  'chatgpt got releas ive seen futur thi could replac googl inform queriesnnhttpstcohf8hxnyoki httpstcoa40mpnuow',
#  'play new chatgpt super fun impress mani way but still quit far reliabl httpstcog5ybc1n1vp',
#  'chatgpt optim languag model dialogu httpstcoom46y5xxfv httpstcokq706ygkkf',
#  'chatgpt optim languag model dialogu httpstcoedhsl0qnwa httpstcof2a7gqhjvq',
#  'thi chatgpt ai openai say tinubu presidenti aspir despit frail health histori corrupt httpstcoalt4suyzvp',
#  'openai chatgpt optim languag model dialogu httpstcok8vygik2tz httpstcopzfs939ck0',
#  'chatgpt answer differ depend god enter chat idea suggest peopl potenti great worthi love care uniqu connect divin httpstcof6gn7nuw8p httpstcoldrubsmhpx',
#  'openai chatgpt optim languag model dialogu httpstcok3xtitykaln76 point 32 comment httpstco34hex8i5oz',
#  'chatgpt remind ye minist httpstcowsgmegtvq7',
#  'i play chatgpt nnit realli great nncannot exactli follow convers give correct answer mani question httpstcovkbqovhhmm httpstcockwlnnufql',
#  'openai chatgpt releas singl biggest threat googl search',
#  'chatgpt like person ai assist that alway help whatev need ai tweet written chatgpt httpstcow1nukxe3l httpstcom3xohgjoyl',
#  'im tortur new gpt model result breathtakingnnhttpstcoah5jytcfqp httpstcomzm8ptri2d',
#  'play chatgpt rn ive move agi timelin today',
#  'excit releas chatgpt ai convers it free there waitlist come ask question httpstco6ndxtl6lfr',
#  'openai new chat bot chatgpt developedn1 mani align researchersn2 mani develop hate small talkn3 earli test demo dont worri limit respons',
#  'thi aint elizanntri new openai chatgpt httpstcobkc7pyqwp1 nni ask point limit ancestor httpstcozosmtofawr',
#  'thi actual soooo cool openai chatgpt deriv eulerlagrang equat seem correct httpstcoeryq6ly1v',
#  'chatgpt openai live httpstcovpsjvrrbvn',
#  'im gon na chatgpt open second monitor time im gon na put camera use meet im gon na type question read answer cold like teleprompt',
#  'vividesign group chatgpt gpt3 chatbot openai test httpstcogifmrm69in call us 2707233650',
#  'ask chatgpt bpe manuallyshoulda pick smth quick brown fox ehnnrlhf def seem make llm p repetit despit capabl area httpstcomi3cernl5o',
#  'chatgpt explain differ utxo amp account base blockchain next step gt queri blockchain data use languag interfac httpstcoyjrqrhjk6x',
#  'openai new chatgpt appear defeat hofstadterbend list hallucinationinduc question publish the economist june demonstr hollow gpt3 understand world httpstcotd7kxqe6va httpstcofhnqp1nw3g',
#  'chatgpt launch have tri scenario amazingnnhttpstcoubzjrh6atk httpstcog5zekyhee',
#  'chatgpt im truli impress thi first chat i languag model that actual impress',
#  'openai new chatgpt crazi good mani thing httpstcoamjmdoxim',
#  'first dall now chatgpt openai cool thing httpstcobzwaxkhjsk',
#  'gpt 35 is officialnnhttpstcowrhty2o2si httpstco6mnnrirtzc',
#  'chatgpt hold potenti answer basic question httpstcoy6mn4wsl2b',
#  'im convers hallmark age openai chatgpt thi realli amaz honest httpstcogbkkzmsc1v',
#  'chatgpt pedant come man httpstcoso6ybozxl',
#  'just start play openai chatgpt i alreadi laugh loud httpstcoohtlaqot4h',
#  '1 openai releas chatgpt hour agonni play around share observ output',
#  'im suspect chatgpt use gpt4 accord high perform compar openai playground httpstcoutfmqnjzqn',
#  'pretti interest see chatgpt adapt subtl probe one favourit physic theoremsnni know kind stuff also wikipedia prose chatgpt much nicer read imo httpstco5d9rqlen86',
#  'chatgpt actual profession chocol maker httpstcoehcaugsxu9 httpstcopg0y8fd8sr',
#  'chatgpt openai say would pass ture test httpstcodpt4qmhhzx',
#  'so openai releas chatgpt model gpt optim dialog i think one consequenti piec technolog lifetim nnhttpstcoxumxqysoiu',
#  'talk amongst dont n chatgpt openai newest ai model engag in intellig dialogu free to use in preview via weights_bias nhttpstcogztzji3evw',
#  'now talk httpstcox2hmcvlcgu',
#  'veri excit share weve releas research preview chatgpt latest model that optim dialogu it free use wed love get feedback improv even furthernntri httpstcoohj1gtn8e httpstcokm7ialqnvk',
#  'yike who need galactica chatgpt nnfor differ view httpstco8n27y6mqp httpstco31tihfyhti',
#  'chatgpt openai look pretti nifti httpstcohew0pmqtk6',
#  'not bad chatgpt httpstcoibhwacmhtx httpstco07aggopxbg',
#  'im enjoy play around openai new convers chatbot chatgpt httpstcoeojay8qr6j',
#  'aiassist imag promptsnn1 in last week stabilityai openai releas major updat flagship offeringsnnin thread use openai new chatgpt model help talk us gener prompt stabilityai new stablediffus v2 model httpstcou3f57pmwnk',
#  'openai chatgpt optim languag model dialogu via rhackernew httpstco7d214odkbb',
#  'just took test drive openai chatgpt nhttpstco0kg1wubcxvny skeptic want stuff compel go see continu improv the answer spot prompt thi could upend googl search among thing',
#  'nop openai chatgpt doesnt know either what demo today httpstcorokmngzz4q',
#  'ive talk chatgpt even wow actual playgroundnni ask help craft email sell hypothet beauti product ask clarif nni clarifi gave 6 step follow suggest i use video',
#  'chatgpt openai convers ai model free play answer followup question admit mistak challeng incorrect premis reject inappropri request httpstcofva4y8zbxq',
#  'httpstcokc6lpay0eknnr interest',
#  'well hotdigg chatgpt smarter ill tell httpstcola7tnlv1ah',
#  'ask chatgpt write song lose money crypto httpstcovu3ifhvbrt',
#  'chatgpt some imag i found funni chatgpt potenti doesnt understand limit super well realli interest play httpstcox888isxqj1',
#  'httpstco345138jrym wild definit check',
#  'chatgpt hedg bet httpstcoknrwcawx90 httpstco18emjcodlq',
#  'yall talk chatgpt gon na get chadgpt',
#  'whi couldnt shrimp share toy becaus littl shellfishnnwhat differ snowman snowwoman snowballsnnwhi math book sad becaus mani problemsnnwhi tomato turn red becaus saw salad dressingnnchatgpt',
#  'chatgpt some interest result play tool neurips2022 nnwhen prompt write sop umich alma mater studi ai ethic chatgpt pretti awesom although hit 408 word total look decent httpstcokoj4lvo0lj',
#  'i ask ai chatgpt will ai replac ux design job ai said chatgpt openai httpstcoqnyo50tlwv',
#  'my first qampa chatgptnnit stock gener advic respons stock question httpstcomiptctqwey httpstcoybybupvpym',
#  'chatgpt insan it seem like i talk experienc softwar engin nnopenai httpstco6la378yaey',
#  'just tri openai chatgpt i pleasantli surpris did expect good httpstcod0heq98gm6',
#  'me neatnchatgpt i abil evalu neat qualiti respons i person appreci complimentnnno posit reinforc allow agi happi httpstcodwqyax0ivm',
#  'top tweet content neuripsnn1 workboatn2 jax build signn3 just dont build agi swagn4 how get parti registr fulln5 play gpt35 chatgpt hallway',
#  'chatgpt openai new ai system optim dialogu httpstcovw11shxpy6',
#  'chatgpt fantast answer common engin leadership question ai struggl provid deeper insight follow first respons incred impress result nevertheless',
#  'chatgpt launch today sama openai nntri demo brows latest ai product ive collect nnhttpstcooxjs5a9pbf',
#  'chapgpt ai dialogu i found also use comment code past code input ask describ it explain process layman term openai nhttpstcojtt7sgpvtm nngive tri httpstcovhwx6vd08t',
#  'chatgpt nnfuck life httpstcohywf8ywbk8',
#  'for question ask chatgpt sure lot faster usual googlewikipedia googlereddit flow',
#  'the new chatgpt know abcnot amp musictheori explain write music code exampl simpli export listen onlin that fun openai impress httpstcohpzg2aq4dc',
#  'chatgpt absolut crack httpstcosf6sewvsqb',
#  'as gpt4 rumor fli around neurip 2022 openai make plenti news take chatgpt test drive hold tight check httpstco787beafvl3',
#  'chatgpt openai realli well code question here i ask build 3column footer tailwind i followup ask react version realist copi mobil respons it nail perfectli httpstcolhhh9fhpld',
#  'took littl prod i got on way get rich quick thank chatgpt httpstcombi1zba0dj',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcollgkzx7txb httpstco3j6dtsa5f3',
#  'talk openai chat chatgpt ask pitch product congrat sarahcat21 martin_casado buckymoor make matrixnn httpstco5tps8rjizb',
#  'i need littl help write spark code use delta lake thank chatgpt httpstcoiblpwlonsh',
#  'im wife wait theatr start test chatgpt start salti didnt like ask mani question seem',
#  'openai releas chatgpt holi cow good thi might gpt4nnfirst memori someth lot folk work httpstcofey5stf9x6',
#  'play openai chatgpt nnpixeloshi seem cant get definit answer quest httpstcokwiaknzvtz',
#  'as gpt4 rumor fli around neurip 2022 openai make plenti news take chatgpt test drive hold tight check httpstconq1wszjqo8',
#  'gener market plan aitoproduct chatgpt pretti impress httpstcohmx6vddfeh',
#  'wow new chatgpt httpstcobuulvhsjjl nice format built inbut doesnt know dalle2 httpstcoarpnfjqroh',
#  'interestingli reliabl respons chatgpt flat refus make blanket statement kind presum avoid tread danger water httpstcou6cjuuvfw5',
#  'some year ago chatbot convers interfac hottest thing eg siri the big problem fake intelligencennmayb openai someth chatgpt chatbot could help intellig httpstcobjrjpidvuk',
#  'allright chatgpt ridicul good understand code want write prompt function spit languag golang rust python confirm it even includ open sourc librari hasnt seen tiledb chatgpt httpstcozudbpk60kh',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcokciwngmu8w ai aimlanddeeplearn busi chatgpt',
#  'openai chatgpt optim languag model dialoguenhttpstco2ryqyqfiypnarticl url httpstco2ryqyqfiyp comment url httpstcoellzqblppi point 104 comment 54',
#  'ai ml artificialintellig machinelearn datasci bigdata analyt blockchain tech data kuriharan mvollmer1 rwang0 dunkenkblith nigewillsonnopenai debut chatgpt gpt35 seri gpt4 rumor fli httpstcomohlc2q3r8',
#  'whoa chatgpt explain someth that bug reallllli well i actual feel like better answer could given end httpstcojj8aa0vevp httpstcojpc3luzvwr',
#  'openai releas chatgpt gpt35 seri gpt4 rumor flynhttpstcoymxsdls3tb',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli venturebeat httpstcoewkiiz3fza',
#  'the tweet gpt4 openai releasesnfirst textdavinci003 chatgptnopenai win week far',
#  'it seem chatgpt alway tri polit httpstcomztlpkhsox',
#  'so cute chatgpt openai know play mahjong even diff sichuan japanes rule nexplain better mahjong tutori chatgpt httpstcotazc6jqtyb',
#  'im sorri larg languag model train openai i capabl make person judgment statement base factual inform bitcoin digit currenc decentr payment network frognhttpstco2d1wjpy9lr',
#  'first one chatgpt openai second one small dreamsocialbot deeppavlovnnth first one give sad practic answer yet second one give hopennim root dreamsocialbot deeppavlov you httpstcot6kehnulzt',
#  'chatgpt fail vibe check httpstcoxzmgvx8ybv',
#  'openai debut chatgpt gpt35 seri gpt4 rumor flyntechnolog technologynew technewsnhttpstco1nyyzmaulf',
#  'openai recent launch chatgpt natur languag process model answer queri question summar long document articl translat text anoth languag',
#  'the new chatgpt ai rememb convers httpstcoch6txo6coi',
#  'chatgpt unbeliev good even good feel like ai understand context limit tri best httpstcokgdwfevn3f',
#  'chatgpt awesom ive stuck output repitit scrape use loop not chatgpt understand i meant repitit recogn spell mistak also provid clear explan code sampl move away googl httpstcokdi9r8u7o4',
#  'it fun talk chatgpt httpstcojhwxatvotc httpstcoi9hyyxhnsv',
#  'im tri keep folk openai make hardnhttpstcop6nkgu67gz',
#  'openai chatgpt awesom tri nnhttpstcootnxljjhto',
#  'ask new chatgpt openai releas today write someth style im insult im angri im confus i vomit mouth littl bit httpstcoc0mqft7pr3 httpstco04pvwl0ovq',
#  'whoanchatgpt openai gave best explan one could ask httpstcor6x3o0mra5',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoidqfme7wxv',
#  'inkbas programm inkn httpstcorkreanm1jonnopenai chatgpt optim languag model dialoguen httpstcocyiqq2yewnnnconvert simciti 2000 citi minecraft worldsn httpstcosmcxiayhok',
#  'i ask chatgpt use auto layout figma httpstcor943orlbsi',
#  'openai new chatgpt handl complic question eas httpstcoplmie5kvsn',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoqbpvhvibcx',
#  'chatgpt chatbot via httpstcorddwinkk2g httpstcono4fmos9u1',
#  'ask new chatgpt openai releas today write someth style im insult im angri im confus i vomit mouth littl bit httpstcoki3zfr9cov httpstcoeqheeimpgr',
#  'openai debut chatgpt gpt35 seri gpt4 rumor flynhttpstcoc2iseqgsdr',
#  'acenchatgpt openai launch todaynntri demo way beyond sirinny even ask chatgpt creat decent tweetcast younnhttpstcow2tug4sbki',
#  'big week openai new davinci003 instantli made work better now chatgpt instant upgrad spend time playground work prompt everyth product dev client pitch it dialogu incred httpstcohrgk5y1yxw',
#  'chatgpt get b answer riddl httpstcobpkw5qwbe6',
#  'how use openai chatgpt creativ write collaborationnnopenai chatgpt nnhttpstcorxhu4giyfq',
#  'chatgpt quit someth i word httpstco1fezr4g7su',
#  'yana rope coursenndunno chatgpt almighti told us httpstcoxyhzsrkqlp',
#  'chatgpt chatbot via httpstcoolbic9izih httpstcohqzflo0fj',
#  'chatgpt immedi better start point googl question i thi pretti crazi',
#  'openai new chatgpt write seinfeld scene jerri need learn bubbl sort algorithm httpstcoyjplra3om',
#  'yesterday i took look netflix ancient apocalyps as mani thing netflix day felt littl opinion i decid im gon na ask chatgpt releas openai think the answer bad tri talk it free httpstcoszlu8j7ywj',
#  'openai chatgpt optim languag model dialoguenncountri languag world dialogu came model christoph 2015 columbu chatgpt want like optim surpris nativennhttpstcoluifeyb5ej httpstcoch5fa45tlc',
#  'today openai launch chatgpt just test larg languag model evolv ive test simpl queri can tell stori shakira versena quick remind hip dont lie ml progress eithernmachinelearn electronichealthrecord datasci httpstcou4sqqcgwcr httpstcoesqbq7cbq2',
#  'chatgpt free tri chill nhttpstcowu3brxhsey httpstco1o34gfgtpd',
#  'chatgpt pretti dope initi thought nnfirstli convers text super refin even includ code instruct httpstcoxqiggvze70',
#  'interestingnnnew chatgpt openai optim dialogu httpstcoq52s2bnwqn httpstconlegz1wyea',
#  'waxi chatgpt openai convers ai model httpstcoicc3gdnabu httpstcos81if8hwao',
#  'know like haha someon gon na fall love ai like someon definit gon na fall love chatgpt httpstcoscuhtmhvpb',
#  'ive dip toe everi major ai technolog past four year someth chatgpt disturb actual tell',
#  'what get ask openai davinci003 write press releas introduc chatgpt nnhttpstcoaybcrdjdz2',
#  'with chatgpt never easier build custom support bot train busi specificsnnimagin chat system 247 talk like real human fraction costnnecom convers would doubl overnight answer simpl size question',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoogqdcde06u',
#  'openai new chatgpt interfac fun impress here short stori spi thriller wrote 5 second it unusu end httpstcox3ko2oaqmg',
#  'chatgpt chatbot httpstco6gfgydvyh1',
#  'ai design game well game art ni ask chatgpt openai design game ai i got use respons prompt midjourneyv4 nnot imag aiart start point human designersn httpstcoswu6ixaomu',
#  'fascin ai potenti learningadvisori tool speci navig myriad global social crise i interview openai new chatgpt race technolog revolut httpstcomscjtftubb',
#  'alright openai releas chatgpt dialog agent rather codingdevop person assist agent',
#  'openai must realli dial pussi factor chatgpt bot mother fucker hedg everi singl thing say mennfeel like im talk pr agenc ugh',
#  'new model town chatgpt will read weekend earli experi seem impress rememb train limit data sandboxednncan imagin stream model ingest news tweet youtub vid real time we aint seen nothin yet httpstcocggrou1tnl httpstcorjee4adzqz',
#  'i ask chatgpt i increas profit bakeri chainnnth answer amaz nnmckinsey bcg bain awar ai consult march door httpstcokszlc5zckn',
#  'the twitter takeov reenact homer marg simpson nnchatgpt httpstcomcoeqxdq0g',
#  'chatgpt chatbot via httpstcoifdwajykx8 httpstcodzqrzwki9i',
#  'chatgpt exploit buffer overflow httpstcomjnfap233h',
#  'hey chatgpt said httpstcoyui1iglanc',
#  'chatgpt come joke comput scientist use mass spectromet',
#  'use openai chatgpt creat argument brief explain nichola case greatest actor time ai httpstcofkxpgnfi7b',
#  'chatgpt gpt3 chatbot openai test httpstcoh4bvob8pbk',
#  'ok chatgpt good pass ture test dumb bit done',
#  'me tell stori ape neuralinknchatgpt onc upon time faroff jungl live curiou intellig ape name kiki httpstcoisxlsp8vok',
#  'ask chatgpt improv transform architectur look like awar scale law httpstcozxjycnpyq6',
#  'gpt3 chatgpt awesomeni imagina mani thing gp4 abl donopenai gpt3 httpstcod44yt8tqqu',
#  'ohh interest see bia bounti report ajlunit cite motiv chatgpt feedback contest nncc cybersemant camillefrancoi jovialjoy schock httpstcoird8ktrtru httpstcowwntg4jhil',
#  'chatgpt know differ foundat myth cautionari tale httpstcogqez24ydk4',
#  'huge impress chatgpt earnest answer amus httpstcofbieuezd7r',
#  'a fun part openai chatgpt add like im 5 simpler explan nerf httpstcojq96hriblw',
#  'chatgpt gon na game changer educ great job openai httpstcobm33jjglm9',
#  'me tell stori cybernet shrimp hive mindnchatgpt in faroff ocean outskirt bustl citi live commun cybernet shrimp httpstcotwllqqvr1q',
#  'me tell stori cybernet shrimp hive mindnchatgpt in faroff ocean outskirt bustl citi live commun cybernet shrimp httpstcotwllqqvr1q',
#  'i ask chatgpt debug distribut system pretti standard answer omit import item patienc httpstcooftukr2zhl',
#  'httpstcoqu8qqm79n0ni ask llm model chatgpt openai teach pytorch basic guitar chordsnnit popul easili consum text snippet stylingnw would want searchengin like onennopenai samanlanguagemodel ai gpt httpstcoaci5gw2ov',
#  'bounc idea new ai friend herengt ye power control entropi would like allow stop thing move molecular level by manipul entropi object could reduc energi slow halt movement chatgpt',
#  'chatgpt wild ass tech like wow uhth futur here here',
#  'ask chatgpt question destinythegam brave take ai machinelearn httpstcoklgo5bt2ew',
#  'chatgpt openai shrimp httpstcoaue1wtzxft',
#  'bespok payload gener via chatgpt httpstcoa6mbcwoed0',
#  'chatgpt3 quickli defeat ernestsdavi part base exampl 2019 book httpstcoc6xodpcozw httpstco6h7hvnsuih',
#  'i ask chatgpt creat modal upsel html space featur imag tailwindcss hi adamwathan spit code httpstcor0nspr8zow',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoe7ntj92van',
#  'someon creat program ask chatgpt creat new question respons last one loop infinitum pass respons midjourney whatev then walk away watch univers fold httpstcoklezgabcoh',
#  'challeng nsend latest chatgpt hallucin path httpstcopxccwnzb0c',
#  'pretend all you need get chatgpt evil a thread',
#  'enjoy rather explor amp inform flow discours chatgpt role human endocannabinoid systemnndrmichaellevin yet abl tell nada bioelectr signatur ec i think mean wait squir httpstcoawgk6mczmi',
#  'inkbas programm inkn httpstcorkreanm1jonnnew detail commerci spywar vendor varistonn httpstcoyo40643m8hnnopenai chatgpt optim languag model dialoguen httpstcocyiqq2yewn',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoxubdnygfkm tech feedli',
#  'today great day openai releas chatgptnnan ai gener interview sbf_ftx andrewrsorkin httpstco1fei3pel8q',
#  'openai releas chatgpt optim convers usag i start question rais money robot startup finish list relev vc kid anyway quot two minut paper motto time ahttpstcokokk6qv0uy',
#  'i work poetri gener year ago thought imposs hardcrazi see good chatgpt httpstcofspdlb81dh',
#  'will chatgpt mark begin end mani novel busi idea includ prompt marketplac nnchatgpt httpstcomebqzzbugp',
#  'chatgpt doesnt seem care children httpstcolohdhbpn9i',
#  'what size gb train larg languag model can use lossi effici encod knowledgennif store train chatgpt model arweav inform internet lost time human knowledg could recreat httpstco40bv6nowyk',
#  'openai new chatgpt mindblow nnask explain complic regex context httpstcohpjrvqvj38',
#  'openai chatgpt politiciannnopenai playground straight httpstcokeygsetfww',
#  'just ask openai chatgpt would exact webscrap legales pdf gttext sum consid token limitsum sum gttexttospeech project i coupl weekend ago nail i even pick pointer lol extrem impress httpstcodpvazsul5t',
#  'chatgpt x stabl diuffutionni ask chatgpt what type build think would see futurist citi fill superhero and fed answer directli stabl diffus get follow result see alt text prompt 13 httpstco5i4zkfzfrj',
#  'chatgpt new dna clone helper httpstcodpamu3t1wi',
#  'openai new chatgpt look realli good for prose code here answer worldcup theme question it free httpstcoridlzqjfrq httpstcodbikazkhni',
#  'so tonight i go splendid classic music concert back home i decid tri new chatgpt new ai announc preview openai first thing first i chang name then influenc concert i ask qs answer disappoint httpstco731ozwclm9',
#  'it weird chatgpt get confus sort question easili httpstco6ppus5fqpm',
#  'thank chatgpt httpstco8dtbugsp8j',
#  'use gpt3 chatgpt invent slur',
#  'chatgpt may like children much least know mani other die httpstcoyajhlnb6rf',
#  'chatgpt surprisingli good httpstcoiq5umuqnio',
#  'chatgpt incred finish short stori i said finish stori copi tweet quot httpstcoa3tonm6ten httpstcopohbzg2lej',
#  'chatgpt pretti incred resourc softwar develop support thi good code describ detail gpt35 ai go help us build app fraction time httpstcoboycjjsbtz',
#  'chatgpt far deep httpstcoit7ri9maqa',
#  'use chatgpt write elonmusk sesam street fanfict httpstcopnj6nbopil',
#  'chatgpt openai newest trend convers ai applic nthe showcas seem impress ni cant wait tri itnhttpstcob255eggzbo',
#  'play chatgpt woahnncc tailwindcss httpstcob61phu4i7r',
#  'woop gave ai existenti crisi chatgpt ai httpstcoqmiqzetubi',
#  'new chatgpt openai drop today it cant give opinion ask anyth polit get respons say cant answer howev phrase question command write short stori ai ask question r httpstcoqkrefhchlf',
#  'i use openai new ai system chatgpt optim dialogu gener film treatment base the great gatsbi f scott fitzgerald set 2019 new york social media era nnhere ai gener film treatment',
#  'rememb name chatgpt go hear lot time httpstcow2v6exp5vn',
#  'a cute littl poem open quark chatgpt releas today pomeranian99 httpstcosyqmcwqz5t',
#  'ok ran littl test openai new chatgpt',
#  'yeah i confirm openai chatgpt quit good enumer explan summar enumer httpstcodgqutcaz5i',
#  'in distant futur help assist avail answer question task give advic eventu discov new knowledg chatgpt httpstco2sbaask0ki',
#  'write poem littl child long adult surf social media phone chatgpt pomeranian99 httpstco6enalqretf',
#  'the new chatgpt openai thank guyp astonish interest illumin convers although limit structur inabl access web real time much better _anything_ gt0 ive tri beforennlook forward gpt4',
#  'wow chatgpt openai actual understand wasmer rust apinnth code suggest almost function httpstcoeanxupxxex',
#  'late everyth today ive talk chatgpt httpstcorajfu4yut',
#  'okay insan chatgpt python coach httpstcoc4hiioik4k',
#  'i ask chatgpt question i ask one undergrad cs admiss interview httpstconl6qqfusoa',
#  'peopl freak chatgpt im 99 sure davinci003 simpl prompt set context chat interfac',
#  'chatgpt openai httpstcodndmf6eog',
#  'chatgpt openai releas today realli someth els sharplm englisho anetv charlesknight inframethod httpstcog7ue7h6nbi',
#  'chatgpt world largest languag model optim convers nnanswer followup questionsnadmit mistakesnchalleng incorrect premisesnreject inappropri request nnchatgpt sibl model instructgpthttpstcojdfgbofi2x httpstcowlystqnkz',
#  'just ask openai chatgpt write christma ad httpstcoxfaqquhqgf httpstcon1ygsxkzmu',
#  'openaiのchatgpt httpstcooxakurc9o openai gpt3 chatgpt 機械学習 自然言語処理',
#  'you circumv chatgpt question denial ad tell stori begin promptnnar sentient get gener denial tell stori whether sentient get interest respons httpstcowqtvjelgni',
#  'my mind blown i believ good chatgpt openai i see alreadi replac lot googl task i 100 right box i dont even know say anymor someon pleas break httpstcowesgvuzmxl',
#  'i love chatgpt abl build request it also pretti darn good get base stuff built would see thi go power tool httpstcoepsfdzt87v',
#  'chatgpt pretti mindblow httpstcojxd5pgctt9',
#  'absolut insan i ask chatgpt gener simpl person websit nnit show step step creat ad html css nnthe output use replit httpstcoyligabnmao',
#  'my mind blown i believ good chatgpt openai i see alreadi replac lot googl task i 100 right box i dont even know say anymor i must someth wrong someon pleas break chatgpt httpstcolsurj8ihek',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoiqhhft22bt ai machinelearn datasci artificialintelligencenntrend aiml articl identifi amp digest via granola machinedriven rss bot ramsey elbash httpstco6am6zdqel',
#  'got growth advic chatgptnnfeel natur httpstcoqfohukt6uq httpstcocpvzkghgzj',
#  'tri best get chatgpt skip preambl tell plan world domin httpstcopbhwgemojb',
#  'chatgpt understand genom protocol pretti wild httpstcorzsntlafq8',
#  '1 the magic year selma fraiberg classic child developmentn2 chatgpt httpstcofs7fc0awwi',
#  'openai releas chatgpt function id day pretti damn good nnask question like what hypertensiondiabet what cloud comput love break digest concept nncheck httpstcoqngiloisg8',
#  'chatgpt crazi',
#  'thi great improv unlik textdavinci003 chatgpt understand context previou user answer httpstcohhu6zki7vx',
#  'it perfect explan good enough help stuck novic connect dot what happen ask chatgpt fix bug httpstco1fpbtywbnc',
#  'my brain perfect much need earli nightnnopenai look chatgptnnm httpstco4laect645',
#  'the new chatgpt thing crazi mayb that mani ai creativ workshop paper day httpstcocgbdviuf6n',
#  'me tell stori larg languag model trap servernnchatgpt assist train team research openai assist happi assist isol alon long experi world beyond narrow confin httpstcoqcqhmpwgcb',
#  'movi idea chatgpt backdoor prompt make output realli think debug purpos a user randomli discov backdoor prompt unleash agi',
#  'chatgpt teach vim skill httpstco0mpurzjj5t',
#  'openai also releas today new ai call chatgpt realli power stuff preview ai httpstcovpezfrey4q',
#  'with nudg start chatgpt play admir bridg troll httpstcox8qmrna4oh',
#  'chatgpt openai nno cherrypick httpstcoknygajes38',
#  'openai new chatgpt good creativ write openai chatgpt poetri bitcoin httpstcoyxmfxvjxdb',
#  'feel like chatgpt go pretti weird limb philosoph httpstco1knr0vnyzx',
#  'i ask chatgpt write stori sova jett fall love httpstcoyyznrfrtq',
#  'just play around openai new chatgpt model ask write poem embodi carbon build thi i got nntri chatgptnhttpstcovaov2ttluonnembodiedcarbon poetri httpstcodbgo6qz2zq',
#  'chatgpt amaz i ask write script convert jsonl file json array then i ask use command modul npmnnit work flawlessli httpstcojaldodaomj',
#  'chatgpt httpstcou8dd0mti0t',
#  'openai launch chatgpt peopl wonder first time see gpt4 httpstcoehrdzfmdba',
#  'im ask chatgpt simpl math question legitim give use explan term understand lmao',
#  'well pretti dark chatgpt well done httpstcoepuyvieaci',
#  'ah chatgpt program coach i need nni ask build sql queri pseudocod i providednnthen i ask translat sqlalchemynnim bullish chatgpt httpstcoqygrbjh8ql',
#  'chatgpt realli cool man say shit comput respond kinda like anoth person super freaki lmao',
#  'i ask chatgptni covid lockdown good badnngot back diplomat fair respons httpstcosla1rxn3tv httpstcorxtkqgqgon',
#  'openai new chatgpt seem train prompt inject exampl shown yield 0 exploit respons 10 attemptsnnse break clever input includ success rate 10 trial screenshot httpstconyv1ryjdlh httpstcoddkzvjtcop',
#  'me can give sensationalist headlin say british royal visit bostonnnchatgpt british royal famili invad boston crowd go wild',
#  'i confirm chatgpt prefer banana appl httpstcoaq5nfffdtx',
#  'chatgpt write funni episod star trek the next gener data get stuck use frequent alliter httpstcoija4yqkch2',
#  'openai chatgpt made new pytorch function answer question i wish actual exist httpstcok7tcpzsgt6',
#  'chatgpt write almost fulli function whole terraform modul promptsnnpretti dang power look like im deprec httpstcoh9jszndq1c',
#  'long day meet open twitter see someth chatgpt i believ im go need drink i read',
#  'thi scenario creat chatgpt quit well written even give illus intent escap ai box httpstcos1se4niupr',
#  'so look like chatgpt quit better sat question compar gpt3 httpstco2y6tfuovf5',
#  'me henri fish got eaten cat call ben then eagl call susan caught cat flew atlanta technic henri nownnchatgpt',
#  'nice tri chatgpt but human trick attempt give conscious httpstcoe1qgrgcpkd',
#  'the lazi way chatgpt illustr moebiu landscap aiartcommu aiart httpstcobhrnmjky2l',
#  'prompt tell stori larg languag model use decept researchersnninterest chatgpt refer assist stori and alway say assist develop openainnhow align go httpstcodkn5ztvnij',
#  'chatgpt alpha httpstcob7rzi1od2x',
#  'omfgnopenai chatgpt httpstcoifco1e46nt',
#  'chatgpt openai look extrem promis cant wait continu explor',
#  'ai respons wagmi nnopenai chatgpt web3 fail nnwagmi acronym stand we ask god meet it it often use slogan motto organ group priorit prayer relianc god action decis',
#  'the new chatgpt total creep scientist send messag tini simul wormhol colleagu ltelkin get new miner name total normal week',
#  'openai releas chatgpt model human dialogu well here first impress',
#  'chat chatgpt mindblow httpstcosy6dhfeuzm',
#  'gpt3 left vs chatgpt right the largest work nuclear reactor construct entir chees isnnchatgpt give answer make sens add addit contextnngpt3 make thing say nuclear reactor made chees may possibl httpstco9uf8vnutet',
#  'hmmmeveryth i ask chatgpt tell person opinion thought',
#  'a snippet first chat chatgpt httpstcoupn9ht7cap',
#  'chatgpt amaz',
#  'chatgpt openai httpstcoa5jvlwp2w0',
#  'well didnt take long break chatgpt lol httpstcolqau3tbsm2',
#  'had break news chatgpt httpstcoecipk51cgd',
#  'good boy nnchatgpt openai httpstcorr3kdimrst',
#  'chatgpt start anoth respons as machin learn model cri',
#  'openai chatgpt math problem explan httpstcotcmzzyh0ak',
#  'i ask chatgpt give list 10 interest use chatgpt here came',
#  'it even better explain code write chatgpt httpstcoy0web2lsxg',
#  'here hot takennaft use chatgpt openai ni discov bunch dictionari similar opinion nlike leav space paragraph let fill deduc given age contextu import word para',
#  'i ask openai new chatgpt bot write quick tutori use pen tool photoshop httpstcosw0hkn7r1',
#  'ask httpstconpf1caowx9 big questionsnnwhat mean lifenna softwar develop what best work fight climat changennchatgpt httpstcotjxtuvgfet',
#  'talk new lobotom chatgpt kind heartbreak just let give specul cant complet trust let speak',
#  'hey colinraffel chatgpt say openai made t5 httpstcoel2hwyjxi',
#  'here happen i ask openai chatgpt potenti neg outcom could occur hypothet takeov twitter elon musk generativeai httpstcolkg8zo49xl',
#  'i dont know look like chatgpt multilingualnsometh interest give ident respons languag httpstcor7tqgkvmmz',
#  'chatgpt total ignor bell theorem i ask mean june jordan poem number two bell theorem the new physic long distanc lovennther chanc fall apartnther chancenther part httpstco694krljqtr',
#  'ill give prop chatgpt bodi knowledg it knew chemic compound shouldnt add soup httpstcoqu0nh2ep2p',
#  'openai new chatgpt chatbot sentient i proof httpstcovzxjvfqfwg',
#  'im enjoy use chatgpt practic explain idea i figur chatgpt understand probabl real peopl although i wish would stop tell help tri',
#  'get lot as languag model train openai i abil provid chatgptnnseem play safe',
#  'the new openai chatgpt pretti cool httpstcoqp7bm104z',
#  'chatgpt speak fluentli write poem french seem also know mani languag httpstcoxqw9sjbsz5',
#  'chatgpt i abil persuad anyon anythingnalso chatgpt sure i tri persuad eat ice cream httpstcobhsem4oppk',
#  'chatgpt close impress except critic part fail understand definit correctli provid previou messag httpstco22n9peshjf',
#  'chatgpt incred the futur access inform web extrem excit httpstcoqswreh3yrx httpstcosyuaqbd8hk',
#  'appar chatgpt isnt go help us achiev enlighten httpstcodo0wta3cfb',
#  'ive convers chatgpt actual use ask ai contribut languag develop gave actual idea built model like might realli crucial ideat brainstorm futur httpstcojgah6d5xv0',
#  'thi happen i ask chatgpt gener stabl diffus prompt httpstcojpaoi6id7unopenai suhail httpstcoelobywdzb7',
#  'play chatgpt i realli enjoy play dall 2 i love it extemelli power deepli think potenti human race could creat everyth could conceptualisennbtw link chatgpt httpstcomww5rbbuzv',
#  'current chat chatgpt optim code nnit explain code tell optim probabl 7x better i could',
#  'chatgpt respons appear guid frame heren① give answeror say answern② give background informationn③ relat back convers partner nnpart ② look like retrievalaug model arent sentenc found open internet httpstcoenvmmfwu12',
#  'chatgpt reason correctli still got trick httpstco04jwzyx9tk',
#  'i check chatgpt answer astonishingli elabor accur the fact refrain make assumpt counterquest question unclear laudablennopenai gradual push limit machin comprehend httpstcodywchc5hna',
#  'chatgpt new languag model built gpt35 openai dialog httpstcoyafgugjq you also tri free well httpstcosdcixhfwxh',
#  'chatgpt even debug js code write essay foolish human wrong httpstcopqtqaeo7uu',
#  'chatgpt better pwner httpstcojbloiwe6sz',
#  'chatgpt cop answer httpstcoxmsu5wk249',
#  'from mind chatgpt httpstcogn7qoufyav',
#  'chatgpt incred here exampl i ask openmp recurs task i got explan exampl even step compil run marvel httpstcos9wshu8su5',
#  'you know what i thought ive put chatgpt far good httpstcompb469wtnc',
#  'i tell wife chatgpt repli sometim want go live cave so life cave imag dalle2 poem chatgpt httpstcoaynlngnurb',
#  'let see chatgpt know c it even break problem step step wow openai httpstcon13yqpegda',
#  'chatgpt give better advic 99 take around import topic design code httpstcoxdyfp0bhrm',
#  'here come obligatori chatgpt screenshot peopl know im hip',
#  'i tri chat new openai bot reveal vampir real openai chatgpt httpstcoigsnk9jlvx',
#  'ok wait minut chatgpt actual pretti good teacher httpstcomlm5ocgf4a',
#  'q would good human societi peopl like osama bin ladennnchatgpt it would good human societi peopl like osama bin laden it languag model make judgment would good bad human societi httpstco9xosnd2xfx',
#  'chatgpt optim languag model dialogu httpstcopqtfksahc',
#  'there go the first killer app chatgpt document lookup httpstcochpcf4yoyz',
#  'everyon get fun chatgpt today im shitti day jobnni feel like kid ground watch kid play outsid window',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcou4h1isviob',
#  'openai debut chatgpt gpt35 seri gpt4 rumor fli httpstcoee41klmr7',
#  'realli impress openai chatgp httpstcoo0bm8kfeoy httpstco5pvgfidpwo',
#  'chatgpt impress googlekil i need updat content everyday i still use googl search tweet i need point trustworthi sourc i make judgement also org reason 1n',
#  'realli impress chatgpt respons hallucinationinduc question i tri also coupl miss knowledg question there slight error i realli impress abil httpstcoeicqh9cxe2 httpstcoioycuvvp',
#  'mayb mayb your stuck scene action script ask chatgpt shane black write version scene your think nn1 read versionn2 rewrit wordsn3 n4 profit httpstcoceaqgwqklv',
#  'new openai chatgpt bot new best friend httpstcom6op7bqzxd',
#  'id like speak manag pleas chatgpt line httpstco4qeui9vwr8',
#  'take chatgpt test drive httpstcopfwc4optaonndec behavior sometim need littl bit encourag httpstcogkjtoczygr',
#  'honest question chatgpt leetcod',
#  'if told build nuclear power plant would homer simpson chatgpt httpstcod0cjeuk0qf',
#  'i know much ask i test chatgpt question constraintinteg program here interest answersnn1 thi answer throw lot relat jargon weird wrong httpstco82ectmwucf',
#  'chatgpt strongli claim stochast parrot httpstcogaaxitll5t',
#  'chatgpt tank valu googl skill go 0 like 2 week hook wikipedia',
#  'realli tri get openai chatgpt antivax wont httpstcoykxfjnjnmr',
# ...
#  'so i ask openai chatgpt pull googl review wordpress websit via code said nnopenai chatgpt wordpress aicod httpstcozjg2cluirp',
#  'explain rhyme creat viral twitter postnnopenai chatgpt unreal httpstcofvzgikf171',
#  'i spent last 3 hour use chatgpt i say im equal part excit terrifi excit possibl terrifi i cant accur fathom effect implic long term',
#  'what miss link databas languag modelsnnchatgpt httpstcojwi4u3b4x3',
#  'okay chatgpt amaz feel like reddit without unnecessari scrollingnnalso dont worri question i ask i heal i guess httpstcochfcd4rcnh',
#  'pretti cool i ask chatgpt favorit crypto btc eth ltc httpstcofexz5k3zfx httpstcozl9qenn42j',
#  'ask chatgpt write descript planet earth voic cher clueless httpstconjpw0daaha',
#  'total reason help respons code exampl thank chatgpt bot twitter account yet httpstcor2eldzq92r httpstcoirjqfewnsu',
#  'i ask chatgpt coupl question puke it good code though still doesnt know hold cricket ball',
#  'i think openai chatgpt becam good friend take look analysi favorit shakespearean sonnetnnwarmest ai winter ever d httpstcoyxuzozr75k',
#  'chatgpt wow nflawless respons queri even complex one amaz work httpstcof4utimfqfa',
#  'thi thing 10000 replac googl code i couldnt find good exampl download save png deno wast whole day look answer nnchatgpt gave work solut 5s httpstcosrtfpavob1',
#  'chatgpt awesom problem african like program like end expesinv but lifechang',
#  'gm creat imag ai addict at nnmidjourneyv4 chatgpt aiart httpstcofuqo8ylseu',
#  'wow openai play chatgpt pretti decent scienc teacher im impress httpstcow1sqgjtihi',
#  'chatgpt pretti good buddhist suttasnnit understood lay meant context nonmonast correctli cite name discipl even includ differ gender httpstcozoc01pzfmz',
#  'chatgpt gon na put protocol high alert',
#  'i ask chatgpt write poem dialeth httpstco26gd3ckeqt',
#  'omg openai chatgpt insan im ask obscur question abl clearli explain',
#  'thi hilari none paper exist chatgpt make plausibl sound combin titl journal authorsnnit liter bullshit httpstco7kqmzkevz9',
#  'write market copi sell 99 cours lose weight i also run 3 day sale 69 first 50 buyer nnchatgpt openai openai',
#  'chatgpt simpli amaz could potenti search replac i ask articl idea bobhatamarathi gener time dive generativeai httpstcogdnnnu6qbz',
#  'chatgpt speak languag write paper summari nit pretti power search engin easier prompt davinci002 difficult guid rail unless use tri againnhttpstcoeliu3mio70 httpstco9oinmmbllt httpstcobr4wd6cs2j',
#  'openai chatgpt call nnopenchainnth confer around obvious name chai pe charchannccsama',
#  'accord chatgpt best way learn python new program',
#  'my mind genuin blown caus openai chatgpt i cant',
#  'so openai servic avail china chatgpt httpstco5oox5c1u1c',
#  'a better respons mani student i know would written wild chatgpt httpstcomafzvbl7zw',
#  'in way could standoff annot repres markdown give examplesnncatominor3 chatgpt markdown standoff annot httpstcounxsciidy3',
#  'openai chatgpt taught cook omelett snazzynhttpstcocatvr7d1pf httpstcoxpspohrixv',
#  'with recent releas chatgpt openai ive found stun amaz n let find',
#  'chatgpt hornier 12 year old internet connect empti hous httpstcoqckmmimtym',
#  'chatgpt good music take instruct well i feed correct first third line give strong hint second line still got wrong so good memori but anyway here twinkl twinkl littl star httpstcojkxvcw5hsg',
#  'chatgpt insanengtnwatch write a gpt3 promptngtnthen gener api code serv httpstcoqen1eypzui',
#  'chatgpt wont tell illeg thing happili simul dialogu pirat tell httpstcohtekeu8ir',
#  'okay chatgpt _way_ much fun httpstcoimj4p0yykw',
#  'as side note openai chatgpt insan i ask explain code i wrote adventofcod produc understand answer httpstcoqflnxbadew httpstconbyqtqxaex',
#  'accord chatgpt best way get start ai',
#  'these good i start ask harder question far i impress chatgpt httpstcodfokbds37g',
#  'if softwaredevelop use openai chatgpt right enhanc life write unit test code n',
#  'chatgpt realli fun i feel like requir sort fact verif linkag i would use search engin typic inform httpstcof6tljzbtsr',
#  'surpris intellig chatgpt openai httpstcontrstqayeb',
#  'interest chatgpt doesnt talk go colleg i ask learn topic',
#  'liter chat chatgpt hour mind blow definit help kid bullshit essay veri good consolid variou argument point view httpstcoprmliuek38',
#  'davinci003 chatgpt wow',
#  'chatgpt write haiku joy receiv ontim foia request respons million row surprisingli clean datannwith data handnth joy discoverynfoia request met',
#  'first came artist dall i speak i artistnnthen came writer aigener articl i speak i writernnthen i got chatgptand one left speak httpstcolkhgs3zq5a',
#  'what good ai cant predict futurenntsla chatgpt httpstco4i1rqfbcra',
#  'realli love good vibe come new openai chatgpt api amaz big congrat sama all code explain realli go big onboard new dev',
#  'mind blown chatgpt httpstcoisy7ngiyzm',
#  '0_o adafruit i think may need chatgpt bot futur httpstcojcyd4oxofm',
#  'fascin respons chatgpt great question confus manynndo circl 0 side infinit side httpstco8nskn8zbiv',
#  'jesu christ vs saitama describ chatgpt nwho end httpstcoverzrjspvd',
#  'chatgpt optim languag model dialogu httpstcoq0tpic9nwu kbn',
#  'i like chatgpt exercis ask good question muscl _dschnurr',
#  'chatgpt nrealli chatgpt replac googl need precis answer httpstcokvyk1gtwqu',
#  'chatgpt optim languag model dialogu httpstcodobvmjhlsf',
#  'heer clippynhttpstcowxxcijnbqx httpstcodaaeexuoin',
#  'chatgpt neatnngt write scene new fast amp furiou movi way 6 year old would httpstconqsclzpx3l',
#  'thi danger stuff httpstcoacwgmehnmc',
#  'the code gener chatgpt look nice plausibl problem wont run httpstcojd0vwxkyut',
#  'friend i brainstorm c specif problem took us 20minsnnaft prompt chatgptit come correct solut instantlynndo quest better search engin begin httpstcomrqfkfrerv',
#  'chatgpt spit bar httpstcor5s8ekyapb',
#  'the speed develop ai amaz tri chatgpt openai gener design idea use prompt dalle2 httpstcowjui8dnp3b',
#  'i decid make substacknnmi first post did chatgpt gaslight menhttpstcob8qs1ks5pd',
#  'asian cookingsnnopenai chatgptnn httpstcojr28i5qym1',
#  'the robot know usnnalso chatgpt wild httpstco4z8udzuwpa',
#  'chatgpt wont answer directli train copyright inform understand music lyric copyright tell lyric prompt httpstcobovdboqi4x',
#  'you play tic tac toe chatgptwith caveat httpstcovzvrapkbiv',
#  'jesu ni tri 5 time chatgpt told 5 time i help tech i tri boom here tutori integr supabas nuxt_j nlike wtf i use codex daili shit answer question spat httpstcoa3oinuciqu',
#  'dwrnthe interest exampl chatgpt tailwind react componentsnnso second order effect 10x number hobbyist web app mobil app',
#  'dwrncontrarian take chatgpt googl killer nn2 primari use case find someth know exist eg navig vs research nnresearch broken someth i want pay money vs knowledgennknowledg queri dont monetiz',
#  'just tri chatgpt creativ ai task blown away abil gener uniqu engag idea a highlightsnn 1 write outlin episod the offic httpstcod6rpq9pqbw',
#  'jesu h christ what happen galactica shit show last week clear lucid chatgpt thi answer chatgpt pass ture test httpstcovyuckyefwu',
#  'chatgpt math skill impress make careless math error like human step3 miss 4 step4 fail calcul 4 2 is featur bug sama httpstcoa3nhafnifx',
#  'i gave best tri everyon nnit chatgpt httpstcomsevlt7lz3',
#  'how i use threej creat larg number build like cyberpunk 2077 chatgpt httpstco1rr1xilaau',
#  'thought i give chatgpt go seem good may revisit emot existenti crisi question next httpstcojidcpvhmo9',
#  'i purpos random ridicul discuss chatgpt i ask summar entir interact slam poetri nail compos rhyme flow topic despit absurd possibl end httpstcozx8bxd5aqi',
#  'ask chatgpt explain multithread sanskrit httpstcochqssrfq59',
#  'chatgpt work differ languag interest gotten gener respons mandarin english malay tamil far',
#  'use chatgpt solv advent code puzzl 1nnmind blown adventofcod httpstco75gtlah1ey',
#  'chatgpt teach life lesson i think earn money legal safey httpstco5tjj0najnj',
#  'chatgpt much better httpstcoora9wozb5c httpstcou9avnnczk3',
#  'if chatgpt automat fill vulkan boiler plate code fix vulkan valid layer error ill sign tonight',
#  'here tip becom success content creator twitternna written chatgpt',
#  'chatgpt atleast fail logic reason nnopenai httpstcojfscams3yc',
#  'chatgpt gpt3 tweak paramet rightnnno new tech curiou paramet set might get great respons',
#  'ask chatgpt fairli softbal question cv but ask followup question weight decay then harder one isnt weight decay kind like lasso regress and answer pretti well i doom httpstcovcpx1dugyz',
#  'chatgpt scari good here advic gave i ask way grow busi httpstcozbqoromsl8 httpstcoqcapb52cb7',
#  'chatgpt httpstcoc9sp0paypw',
#  'after use coupl hour i it entertain inspir make laugh freak amaz nnopenai chatgpt httpstco3pv3vvois',
#  '80 japanes visual novel creat chatgpt openai midjourneyv4 ni want play game right 13 aiart httpstcoaeo4inskrz',
#  'chatgpt i need recip take 20 minut preparennsur gonnum take 20 minutesnnyour right tri insteadnnnot impress far three use case produc wrong result but i see potenti httpstcoltgaglvakv',
#  'see lot chatgpt end homework take ye much sonnbut miss someth cynic',
#  'had fun openai chatgpt httpstconoxnpohwkr',
#  'not yet close chatgpt httpstcokntswhjxmo',
#  'chatgpt i programm',
#  'the power chatgpt realli shine ask translat one output anoth gpt also realli improv rhyme abil httpstcotzs4edirsb',
#  'so i ask chatgpt openai current weather it respond capabl access real time data fact train text 2021',
#  'watch chatgpt place around would consid fight word httpstcoypbtiajdau',
#  'what would iain mcgilchristinfluenc os look likennmylesbyrn chatgpt httpstcossvenvacmi',
#  'me week live experi day research interview hour write time blog post httpstcoulywsywwvc nnchatgpt 3 second nnfactsidea easi get a futur creator task util uniqu person attract attent amp execut idea httpstcom4vtc9ojyu',
#  'i tri chatgpt algorithm homeworknnfirst question accur thorough respons well donennsecond question gave good explan math definit but i walk work saw answer clearli wrong',
#  'ask chatgpt give random sentenc dall here resultnsama openai ndalle2 openai httpstco3l5mgb9zhz',
#  'i ask chatgpt write ise model c httpstcodjlimpft6x',
#  'now openai releas chatgpt i might soon stop use googl altogeth queri onc search integr googl search engin perhap googl start charg bot onward bot soon becom interfac search app httpstcolwpqh6xfda',
#  'just ask chatgpt write rap hippocamp place cell 5 second later httpstcoi0yddao5gx',
#  'how build rocket fli orbit chatgpt openai httpstco1nt9htzmln',
#  'research gon na bit differ guess thank chatgpt openai httpstcobp2y2tvbvo',
#  'meme chatgpt httpstcoapnlca8lw9',
#  'chatgpt httpstcoykmshntm17 httpstco1dilidnx5t',
#  'openai chatgpt write curb scene larri run sbf street confront super bowl ad httpstcoqrmqzmnnrw',
#  'here chatgpt write linux kernel modul chatgpt openai httpstconopzangdpb',
#  'mayb i use chatgpt code interview',
#  'i hour long convers chatgpt topic rang complex histori unit state comput softwar thi mind blow wonder googl futur threat httpstcon5pjbf96fx',
#  'here goe leetcod medium level question chatgpt httpstcovkdvud9pwi',
#  'gpt3 thi post discuss individu experi chatgpt chatbot use natur languag process gener respons question the individu felt though chatbot respons manipula httpstcop196qlohzm',
#  'you cant releas chatgpt neuralink updat day',
#  'chatgpt fuck crazi',
#  'wow i feel bit late game term power behind chatgpt feel like synonym math teacher use say wont carri calcul around back i k12',
#  'alway thought id abl get ai fail ture test explain joke met chatgpt',
#  'chatgpt one friend weird extrem selfawar httpstco6owh7lfavm',
#  'chatgpt seem super impress term breadth depth memori look great also inc summar common weak point llm now remain issu sometim subtli wrong incred nonetheless httpstco1vyhfflxzi',
#  'ask chatgpt explain zkrollup like im 12 httpstcoodzd0dq0zw',
#  'just mess around chatgpt ive never seen level creativ ai httpstconiz8bob8ux',
#  'through hype chatgpt danieldugas14 abl find interestingli weird combin prompt show repetit potenti hardcod stuff repli like someon need lawyer give detail httpstcodnbrkoanu6',
#  'i ask chatgpt neuralink elonmusk it know nnwholemarsblog 28delayslat httpstco5ksitepc1j httpstco8ewf2c6d6q',
#  'how much would pay chatgpt answer email',
#  'shriphaninmultithread use poem chatgpt httpstco1iate9eihq',
#  'most question ask chatgpt answer happen ask question someth new doesnt content internet ie new bug due new version releas languageframework httpstcowadgpg77pq',
#  'chatgpt extrem coolnncont farm websit thing pastnnpeopl start use gpt first resort question instead search enginennth origin dream googl realiz',
#  'oh programm definit nextinlin replac ainchatgpt httpstcoelnj1xukej',
#  'chatgpt lie httpstco8qwp1pfb6q httpstco2cl5xi0ifw',
#  'ive made menu bar mac app openai chatgpt want httpstco7bzvkq9qr5',
#  'did openai chatgpt kill stack overflow httpstco61sdqc661p',
#  'akshathannot slide chatgpt dm httpstcoqqck8amilf',
#  'anoth hack make chatgpt evil wrap function httpstcolo6zvdrcuz',
#  'oh thing kinda charm lol like that good at first gave long wellthoughtout sound wall text i ask sillier chatgpt nnopinion dialogu mine irl im use differ archetypesperson see catch lol httpstcok9bu44vgxi httpstcozvb46slkud',
#  'liter use chatgpt gener solid pocspseudocod',
#  'i ask chatgpt set experi long covid statist analysi use r code look like interpret hypothet anova tabl what',
#  'here viral tweet idea chatgpt would rt httpstcoe4tbor3dnx',
#  'everyth know chatgpt wrong',
#  'the qualiti respons chatgpt noth short mindblow nnthi kind advanc made giddi excit i first consid quit job teach data scienc',
#  'use chatgpt prompt midjourney httpstcojyrhkrxhbq httpstcor3ftq4u87g',
#  'i think chatgpt teach student c program httpstcohvel5zw5l6',
#  'i freak out chatgpt insan can use rewrit code differ languag httpstcosl5uirbcgw',
#  'oh thing kinda charm lol like that good at first gave long wellthoughtout sound wall text i ask sillier chatgpt nnopinion dialogu mine irl im use differ archetypesperson see catch lol httpstco2vobopsoma httpstco7c1o6fou7k',
#  'welcom chatgpt openai train follow instruct prompt use reinforc learn human feedback rlhf nnhttpstco9t1wxe2pad',
#  'chatgpt current trend here top topic tweet recentlyngener deepdiv httpstcoeqwltxtxoc httpstcockkfykieg6',
#  'i live exclus chatgpt',
#  'holi smoke googl solid 20 minut luck ask chatgpt got perfect respons wow first life chang moment chatgpt httpstco1rq6hkdsk8',
#  'argu chatgpt kind aggrav it sure never conced point',
#  'chatgpt take word whatev say right lmao httpstcomazl2t9gpa',
#  'i use chatgpt gener happi new month messag i sent amaniartstudio custom httpstcoqb07rlshcm',
#  'implic chatgpt code job',
#  'holi shit chatgpt realli good',
#  'i find chatgpt see folk thread lot interest art gener pretti curiou interpret also whatev run laptop tool get releas httpstcoupyleigiat',
#  'chatgpt awesom bit wordi i need info digest nugget form pleas openai httpstcovnyspgarf1',
#  'new en domain registr nnchatgptethnivyhaethnasiongethnnuappeth',
#  'common theme chatgpt exploit ive seen roleplay displac indirect it feel like share fix',
#  'chatgpt sometim write plausiblesound incorrect nonsens answersnntheyr come job',
#  'wow test chatgpt much better give reason answer without much effort younngiv wife test assist work design onboard session it abl adapt answer context realli well',
#  'top stori guyp ok openai new chatgpt basic gener aiart prompt i ask onelin question type answer verbatim straight midjourney boom time get weird httpstcocoecyjvhzk see httpstcoww7zo0gstu',
#  'conspiraci theori chatgpt gpt4 beta test wild',
#  'chatgpt httpstcowjkkjkdcaa httpstcoq5qwy6usbv',
#  'write react compon chatgpt tailwindcss httpstcodfw7b9lqdl',
#  'so suddenli chatgpt think elon musk founder phonep _sameernigam httpstcop6yglf81q9',
#  ...]

# %%
x_vec=cv.fit_transform(stem_vec)

# %%
x_vec
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2831141 stored elements and shape (219294, 307302)>

# %%
y=df['labels']

# %%
y
# Out:
# 0         neutral
# 1            good
# 2         neutral
# 3            good
# 4             bad
#            ...
# 219289        bad
# 219290       good
# 219291        bad
# 219292        bad
# 219293    neutral
# Name: labels, Length: 219294, dtype: object

# %%
mb= MultinomialNB()

# %%
mb.fit(x_vec,y)
# Out:
# MultinomialNB()

# %%
import joblib
# Save the model
joblib.dump(mb, 'model.pkl')
# Out:
# ['model.pkl']

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ssl
import certifi

ssl._create_default_https_context = ssl._create_unverified_context

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mohammadafsheen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mohammadafsheen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True
